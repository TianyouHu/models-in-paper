# %% [markdown]
# ### code to upload files which are not folders in colab

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-0f5f8cac-5f10-4dff-ab40-5f39e6a28126" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f5f8cac-5f10-4dff-ab40-5f39e6a28126">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pepsi.jpg to pepsi.jpg

# %% [markdown]
# ### code to upload folder

# %%
from google.colab import drive#drive means google drive
drive.mount('/content/drive/')#this is the default directory of google drive
#Go to URL in browser is to make sure I'm the owner of the account
#After this section the drive files has been upload
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ln -s "/content/drive/My Drive/Colab Notebooks/" "/content/"
#Someone on the internet says move the folder into another path 
#which is not "drive" can speed up the code

# %% [markdown]
# # Fully Convolutional Networks for semantic segmentation
#
# In an image for the semantic segmentation, each pixcel is labeled with the class of its enclosing object. The semantic segmentation problem requires to make a classification at every pixel.
#
# First, download data from:
#
# https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view
#
# and save the downloaded data folder in the current directory.

# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid", {'axes.grid' : False})
# enter your path here
dir_seg = "/content/Colab Notebooks/dataset1/annotations_prepped_train/"# annotations_prepped_train   Don't forget to write "." in front of /
dir_img = "/content/Colab Notebooks/dataset1/images_prepped_train/"# images_prepped_train

ldseg = np.array(os.listdir(dir_seg))

## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
## Read first image from annotations_prepped_train and images_prepped_train with path "dir_seg +"/"+ fnm"
#if using imread here, seg will be 2-dimension instead of 3-dimension
seg = cv2.imread(dir_seg  +"/"+ fnm ) # image from annotations_prepped_train (360, 480, 3)
img_is = cv2.imread(dir_img  +"/"+ fnm )# image from images_prepped_train
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma-mi+1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

# Plot original image from images_prepped_train image:
plt.imshow(img_is)
# Plot all class from annotations_prepped_train image:
fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 0016E5_05430.png
# seg.shape=(360, 480, 3), img_is.shape=(360, 480, 3)
# minimum seg = 0, maximum seg = 11, Total number of segmentation classes = 12

# %% [markdown]
# From the first section, we can see there are 12 segmentation classes and the image is from a driving car.
#
# Assign color to annotations_prepped_train image

# %%
import random
def give_color_to_seg_img(seg,n_classes):
    seg_img=np.zeros(seg.shape) #note:seg is a 3_dimension image!!
    for i in range(n_classes):
        indexh=np.where(seg==i)[0]
        indexw=np.where(seg==i)[1]
        seg_img[indexh,indexw,:]= sns.color_palette("hls", n_classes)[i]
    return(seg_img)

input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    #np.random.choice() choose random number from [0,len(ldseg)), returns to a array. 3 is size. False means cannot choose repeated numbers
    # randomly select on the training image
    fnm = fnm.split(".")[0]#get the name of original image and discard ".png"
    seg = cv2.imread(dir_seg  +"/"+ fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img  +"/"+ fnm + ".png")
    # assign color to its annotations_prepped_train image
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(output_height , output_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %% [markdown]
# To simplify the problem, I will reshape all the images to the same size: (224,224).
#
# Since this is the image shape used in VGG and FCN model in this blog uses a network that takes advantage of VGG structure. The FCN model becomes easier to explain when the image shape is (224,224).

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        # 1 means input a colored images, while 0 or 2 represent grayscale image. other numbers will get the colored output
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):    
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

  
images = os.listdir(dir_img)
images.sort()#sort it
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :#zip is generator and returns to list[(),(),......],im and seg here are the names of images
    X.append( getImageArr(dir_img +"/"+ im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg +"/"+ seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
#X,Y are arrays. There shapes are down below. 367 images in total; So X,Y contains all the trained original images and annotation images
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %% [markdown]
# Import Keras and Tensorflow to develop deep learning FCN models

# %%
## Import usual libraries
import tensorflow as tf
from tensorflow.python.keras.backend import set_session#this sentence is changed 
#or it will raise errors : No module named 'keras.backend.tensorflow_backend'; 'keras.backend' is not a package
import keras, sys, time, warnings
from tensorflow.python.keras.models import *#these 2 sentence are changed to make Input() works later
from tensorflow.python.keras.layers import *

tf.compat.v1.disable_eager_execution()

import pandas as pd 
warnings.filterwarnings("ignore")

###############################################
  
# check python, keras, and tensorflow version
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras# del delete the variables
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.6.9 (default, Jul 17 2020, 12:50:27)
# [GCC 8.4.0]
# keras version 2.4.3
# tensorflow version 2.3.0

# %% [markdown]
# # From classifier to dense FCN
# The recent successful deep learning models such as VGG are originally designed for classification task. The network stacks convolution layers together with down-sampling layers, such as max-pooling, and then finally stacks fully connected layers. Appending a fully connected layer enables the network to learn something using global information where the spatial arrangement of the input falls away.
#
# # Fully convolutional network
# For the segmentation task, however, spatial infomation should be stored to make a pixel-wise classification. FCN allows this by making all the layers of VGG to convolutional layers.
#
# Fully convolutional indicates that the neural network is composed of convolutional layers without any fully-connected layers usually found at the end of the network. Fully Convolutional Networks for Semantic Segmentation motivates the use of fully convolutional networks by "convolutionalizing" popular CNN architectures e.g. VGG can also be viewed as FCN.
#
# The following method is FCN8 from Fully Convolutional Networks for Semantic Segmentation. It deplicates VGG16 net by discarding the final classifier layer and convert all fully connected layers to convolutions. Output image size is (output_height, output_width) = (224,224).
#
# # Upsampling
# The upsampling layer brings low resolution image to high resolution. There are various upsamping methods. This presentation gives a good overview. For example, one may double the image resolution by duplicating each pixcel twice. This is so-called nearest neighbor approach and implemented in Keras's UpSampling2D.
#
# These upsampling layers do not have weights/parameters so the model is not flexible. Instead, FCN8 uses upsampling procedure called backwards convolusion (sometimes called deconvolution) with output stride. This method simply reverses the forward and backward passes of convolution and implemented in Keras's Conv2DTranspose.
#
# In FCN8, the upsampling layer is followed by several skip connections. See details at Fully Convolutional Networks for Semantic Segmentation.
#
# Downloaded VGG16 weights from fchollet's Github:
# https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
#
# This is a massive .h5 file (57MB).

# %%
# location of VGG weights
VGG_Weights_path = "/content/Colab Notebooks/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %% [markdown]
# ## FCN32
# ### code down below is about FCN32

# %%
def FCN32( nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,  
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 
    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    #actually the shape of tf.python.keras.layers.Input is [batch_size,224,224,3], batch_size is None here.
    
    # Block 1  default: using bias
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x1)
    x1 = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x1)

    # Block 2
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x1)
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x2)
    x2 = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x2)
    # Block 3
    x3 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x2)
    x3 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x3)
    x3 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x3)
    x3 = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x3)
    # Block 4
    x4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x3)
    x4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x4)
    x4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x4)
    x4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x4)
    # Block 5
    x5 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(x4)
    x5 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x5)
    x5 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x5)
    x5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x5)#now x.shape is (batch_size,7,7,512)
    
    n = 4096
    
    x6 = Conv2D(n, (3, 3), activation='relu', padding='same', name='conv6',data_format=IMAGE_ORDERING )(x5)
    x7 = Conv2D(n_classes, (3, 3), activation='relu', padding='same',name='conv7', data_format=IMAGE_ORDERING )(x6)
    #now conv7.shape is (batchsize,7,7,4096)
    ## 32 times upsampling for cov7
    upsampled_conv7=UpSampling2D(size=(32,32),interpolation='bilinear')(x7)#shape [batchsize,224,224,4096]
    #combine the upsampling and softmax
    prediction=Softmax(axis=-1)(upsampled_conv7)
    #output image shape
    # create model and load weight
    model=Model(inputs=img_input,outputs=prediction)
    return model
model32 = FCN32(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)


model32.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 7, 7, 4096)        18878464
# _________________________________________________________________
# conv7 (Conv2D)               (None, 7, 7, 12)          442380
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 224, 224, 12)      0
# _________________________________________________________________
# softmax (Softmax)            (None, 224, 224, 12)      0
# =================================================================
# Total params: 34,035,532
# Trainable params: 34,035,532
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Split between training and testing data

# %%
from sklearn.utils import shuffle
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)#array which has "number of images*train rate" elements
index_test  = list(set(range(X.shape[0])) - set(index_train))#return to a list containing all the test index
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# # Train the model FCN32
# ##I trained 300 epochs, each one spends 10 seconds

# %%
from tensorflow.python.keras import optimizers# keras is not tensorflow.python.keras. This sentence should be the same as the one before


# Training data
sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model32.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model32.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=300,verbose=2)#this sentence feed data to the model,
                                                   #the sentences before it just create the model with specific dimension and shape(structure)
    #default batch size=32
# Out:
# Train on 311 samples, validate on 56 samples
# Epoch 1/300
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 311/311 - 5s - loss: 2.4651 - accuracy: 0.2913 - val_loss: 2.4264 - val_accuracy: 0.3188
# Epoch 2/300
# 311/311 - 3s - loss: 2.3744 - accuracy: 0.3204 - val_loss: 2.3020 - val_accuracy: 0.3188
# Epoch 3/300
# 311/311 - 3s - loss: 2.1858 - accuracy: 0.3204 - val_loss: 1.9887 - val_accuracy: 0.3236
# Epoch 4/300
# 311/311 - 3s - loss: 1.7858 - accuracy: 0.4682 - val_loss: 1.6039 - val_accuracy: 0.5818
# Epoch 5/300
# 311/311 - 3s - loss: 1.4554 - accuracy: 0.5889 - val_loss: 1.3828 - val_accuracy: 0.5618
# Epoch 6/300
# 311/311 - 3s - loss: 1.3530 - accuracy: 0.5751 - val_loss: 1.2897 - val_accuracy: 0.5852
# Epoch 7/300
# 311/311 - 3s - loss: 1.2275 - accuracy: 0.6092 - val_loss: 1.2039 - val_accuracy: 0.6115
# Epoch 8/300
# 311/311 - 3s - loss: 1.1731 - accuracy: 0.6213 - val_loss: 1.1460 - val_accuracy: 0.6309
# Epoch 9/300
# 311/311 - 3s - loss: 1.1392 - accuracy: 0.6348 - val_loss: 1.1484 - val_accuracy: 0.6088
# Epoch 10/300
# 311/311 - 3s - loss: 1.1103 - accuracy: 0.6462 - val_loss: 1.0662 - val_accuracy: 0.6584
# Epoch 11/300
# 311/311 - 3s - loss: 1.0638 - accuracy: 0.6557 - val_loss: 1.0542 - val_accuracy: 0.6635
# Epoch 12/300
# 311/311 - 3s - loss: 1.0394 - accuracy: 0.6664 - val_loss: 1.0454 - val_accuracy: 0.6558
# Epoch 13/300
# 311/311 - 3s - loss: 1.0461 - accuracy: 0.6599 - val_loss: 1.0481 - val_accuracy: 0.6673
# Epoch 14/300
# 311/311 - 3s - loss: 1.0130 - accuracy: 0.6774 - val_loss: 1.0084 - val_accuracy: 0.6885
# Epoch 15/300
# 311/311 - 3s - loss: 1.0093 - accuracy: 0.6791 - val_loss: 0.9835 - val_accuracy: 0.6847
# Epoch 16/300
# 311/311 - 3s - loss: 0.9836 - accuracy: 0.6854 - val_loss: 1.0230 - val_accuracy: 0.6806
# Epoch 17/300
# 311/311 - 3s - loss: 1.0006 - accuracy: 0.6785 - val_loss: 0.9578 - val_accuracy: 0.6942
# Epoch 18/300
# 311/311 - 3s - loss: 0.9623 - accuracy: 0.6930 - val_loss: 0.9756 - val_accuracy: 0.6928
# Epoch 19/300
# 311/311 - 3s - loss: 0.9514 - accuracy: 0.6974 - val_loss: 0.9670 - val_accuracy: 0.6853
# Epoch 20/300
# 311/311 - 3s - loss: 0.9382 - accuracy: 0.7008 - val_loss: 1.0256 - val_accuracy: 0.6789
# Epoch 21/300
# 311/311 - 3s - loss: 0.9413 - accuracy: 0.6967 - val_loss: 0.9257 - val_accuracy: 0.7117
# Epoch 22/300
# 311/311 - 3s - loss: 0.9149 - accuracy: 0.7036 - val_loss: 0.9367 - val_accuracy: 0.7012
# Epoch 23/300
# 311/311 - 3s - loss: 0.8995 - accuracy: 0.7115 - val_loss: 0.9024 - val_accuracy: 0.7103
# Epoch 24/300
# 311/311 - 3s - loss: 0.9095 - accuracy: 0.7028 - val_loss: 0.9045 - val_accuracy: 0.7162
# Epoch 25/300
# 311/311 - 3s - loss: 0.8765 - accuracy: 0.7198 - val_loss: 0.9122 - val_accuracy: 0.7125
# Epoch 26/300
# 311/311 - 3s - loss: 0.8741 - accuracy: 0.7205 - val_loss: 0.8862 - val_accuracy: 0.7207
# Epoch 27/300
# 311/311 - 3s - loss: 0.8551 - accuracy: 0.7280 - val_loss: 0.8878 - val_accuracy: 0.7164
# Epoch 28/300
# 311/311 - 3s - loss: 0.8510 - accuracy: 0.7279 - val_loss: 0.8592 - val_accuracy: 0.7276
# Epoch 29/300
# 311/311 - 3s - loss: 0.8736 - accuracy: 0.7210 - val_loss: 0.8520 - val_accuracy: 0.7285
# Epoch 30/300
# 311/311 - 3s - loss: 0.8178 - accuracy: 0.7404 - val_loss: 0.9298 - val_accuracy: 0.7012
# Epoch 31/300
# 311/311 - 3s - loss: 0.8090 - accuracy: 0.7449 - val_loss: 0.8300 - val_accuracy: 0.7383
# Epoch 32/300
# 311/311 - 3s - loss: 0.7995 - accuracy: 0.7461 - val_loss: 0.8323 - val_accuracy: 0.7389
# Epoch 33/300
# 311/311 - 3s - loss: 0.7984 - accuracy: 0.7430 - val_loss: 0.8323 - val_accuracy: 0.7400
# Epoch 34/300
# 311/311 - 3s - loss: 0.7564 - accuracy: 0.7654 - val_loss: 0.7913 - val_accuracy: 0.7493
# Epoch 35/300
# 311/311 - 3s - loss: 0.7684 - accuracy: 0.7585 - val_loss: 0.7951 - val_accuracy: 0.7538
# Epoch 36/300
# 311/311 - 3s - loss: 0.7365 - accuracy: 0.7712 - val_loss: 0.8419 - val_accuracy: 0.7335
# Epoch 37/300
# 311/311 - 3s - loss: 0.7486 - accuracy: 0.7667 - val_loss: 0.7908 - val_accuracy: 0.7483
# Epoch 38/300
# 311/311 - 3s - loss: 0.7278 - accuracy: 0.7699 - val_loss: 0.7845 - val_accuracy: 0.7573
# Epoch 39/300
# 311/311 - 3s - loss: 0.7052 - accuracy: 0.7807 - val_loss: 0.7783 - val_accuracy: 0.7548
# Epoch 40/300
# 311/311 - 3s - loss: 0.6971 - accuracy: 0.7834 - val_loss: 0.7767 - val_accuracy: 0.7551
# Epoch 41/300
# 311/311 - 3s - loss: 0.6777 - accuracy: 0.7894 - val_loss: 0.8097 - val_accuracy: 0.7488
# Epoch 42/300
# 311/311 - 3s - loss: 0.6679 - accuracy: 0.7952 - val_loss: 0.7783 - val_accuracy: 0.7599
# Epoch 43/300
# 311/311 - 3s - loss: 0.6575 - accuracy: 0.7978 - val_loss: 0.8056 - val_accuracy: 0.7449
# Epoch 44/300
# 311/311 - 3s - loss: 0.7177 - accuracy: 0.7764 - val_loss: 0.7633 - val_accuracy: 0.7621
# Epoch 45/300
# 311/311 - 3s - loss: 0.6387 - accuracy: 0.8035 - val_loss: 0.7457 - val_accuracy: 0.7714
# Epoch 46/300
# 311/311 - 3s - loss: 0.6258 - accuracy: 0.8091 - val_loss: 0.7495 - val_accuracy: 0.7697
# Epoch 47/300
# 311/311 - 3s - loss: 0.6330 - accuracy: 0.8062 - val_loss: 0.7300 - val_accuracy: 0.7743
# Epoch 48/300
# 311/311 - 3s - loss: 0.6246 - accuracy: 0.8090 - val_loss: 0.7668 - val_accuracy: 0.7666
# Epoch 49/300
# 311/311 - 3s - loss: 0.5986 - accuracy: 0.8185 - val_loss: 0.7094 - val_accuracy: 0.7847
# Epoch 50/300
# 311/311 - 3s - loss: 0.5978 - accuracy: 0.8190 - val_loss: 0.7539 - val_accuracy: 0.7727
# Epoch 51/300
# 311/311 - 3s - loss: 0.6437 - accuracy: 0.8003 - val_loss: 0.7079 - val_accuracy: 0.7848
# Epoch 52/300
# 311/311 - 3s - loss: 0.5714 - accuracy: 0.8277 - val_loss: 0.7585 - val_accuracy: 0.7752
# Epoch 53/300
# 311/311 - 3s - loss: 0.5690 - accuracy: 0.8280 - val_loss: 0.7002 - val_accuracy: 0.7932
# Epoch 54/300
# 311/311 - 3s - loss: 0.5502 - accuracy: 0.8344 - val_loss: 0.8656 - val_accuracy: 0.7543
# Epoch 55/300
# 311/311 - 3s - loss: 0.5867 - accuracy: 0.8207 - val_loss: 0.7125 - val_accuracy: 0.7870
# Epoch 56/300
# 311/311 - 3s - loss: 0.5388 - accuracy: 0.8388 - val_loss: 0.7135 - val_accuracy: 0.7859
# Epoch 57/300
# 311/311 - 3s - loss: 0.5736 - accuracy: 0.8240 - val_loss: 0.7071 - val_accuracy: 0.7857
# Epoch 58/300
# 311/311 - 3s - loss: 0.5209 - accuracy: 0.8455 - val_loss: 0.7003 - val_accuracy: 0.7924
# Epoch 59/300
# 311/311 - 3s - loss: 0.5443 - accuracy: 0.8355 - val_loss: 0.7422 - val_accuracy: 0.7728
# Epoch 60/300
# 311/311 - 3s - loss: 0.5277 - accuracy: 0.8431 - val_loss: 0.7079 - val_accuracy: 0.7881
# Epoch 61/300
# Epoch 107/300
# 311/311 - 3s - loss: 0.3862 - accuracy: 0.8849 - val_loss: 0.7196 - val_accuracy: 0.7988
# Epoch 108/300
# 311/311 - 3s - loss: 0.3826 - accuracy: 0.8863 - val_loss: 0.7179 - val_accuracy: 0.7998
# Epoch 109/300
# 311/311 - 3s - loss: 0.3829 - accuracy: 0.8863 - val_loss: 0.7331 - val_accuracy: 0.7952
# Epoch 110/300
# 311/311 - 3s - loss: 0.3906 - accuracy: 0.8829 - val_loss: 0.7251 - val_accuracy: 0.7992
# Epoch 111/300
# 311/311 - 3s - loss: 0.3836 - accuracy: 0.8854 - val_loss: 0.7213 - val_accuracy: 0.7992
# Epoch 112/300
# 311/311 - 3s - loss: 0.3828 - accuracy: 0.8857 - val_loss: 0.7234 - val_accuracy: 0.7999
# Epoch 113/300
# 311/311 - 3s - loss: 0.3808 - accuracy: 0.8867 - val_loss: 0.7306 - val_accuracy: 0.7965
# Epoch 114/300
# 311/311 - 3s - loss: 0.3886 - accuracy: 0.8829 - val_loss: 0.7228 - val_accuracy: 0.7981
# Epoch 115/300
# 311/311 - 3s - loss: 0.3818 - accuracy: 0.8859 - val_loss: 0.7307 - val_accuracy: 0.7966
# Epoch 116/300
# 311/311 - 3s - loss: 0.3805 - accuracy: 0.8862 - val_loss: 0.7323 - val_accuracy: 0.7978
# Epoch 117/300
# 311/311 - 3s - loss: 0.3825 - accuracy: 0.8850 - val_loss: 0.7299 - val_accuracy: 0.7944
# Epoch 118/300
# 311/311 - 3s - loss: 0.3848 - accuracy: 0.8842 - val_loss: 0.7310 - val_accuracy: 0.7995
# Epoch 119/300
# 311/311 - 3s - loss: 0.3799 - accuracy: 0.8860 - val_loss: 0.7446 - val_accuracy: 0.8000
# Epoch 120/300
# 311/311 - 3s - loss: 0.3863 - accuracy: 0.8838 - val_loss: 0.7298 - val_accuracy: 0.7987
# Epoch 121/300
# 311/311 - 3s - loss: 0.3775 - accuracy: 0.8872 - val_loss: 0.7370 - val_accuracy: 0.7972
# Epoch 122/300
# 311/311 - 3s - loss: 0.3782 - accuracy: 0.8867 - val_loss: 0.7346 - val_accuracy: 0.7975
# Epoch 123/300
# 311/311 - 3s - loss: 0.3802 - accuracy: 0.8856 - val_loss: 0.7370 - val_accuracy: 0.7975
# Epoch 124/300
# 311/311 - 3s - loss: 0.3742 - accuracy: 0.8883 - val_loss: 0.7401 - val_accuracy: 0.7992
# Epoch 125/300
# 311/311 - 3s - loss: 0.3739 - accuracy: 0.8885 - val_loss: 0.7580 - val_accuracy: 0.7944
# Epoch 126/300
# 311/311 - 3s - loss: 0.3763 - accuracy: 0.8875 - val_loss: 0.7406 - val_accuracy: 0.7987
# Epoch 127/300
# 311/311 - 3s - loss: 0.3740 - accuracy: 0.8884 - val_loss: 0.7384 - val_accuracy: 0.7989
# Epoch 128/300
# 311/311 - 3s - loss: 0.3737 - accuracy: 0.8885 - val_loss: 0.7438 - val_accuracy: 0.7977
# Epoch 129/300
# Epoch 152/300
# 311/311 - 3s - loss: 0.3683 - accuracy: 0.8896 - val_loss: 0.7646 - val_accuracy: 0.7967
# Epoch 153/300
# 311/311 - 3s - loss: 0.3684 - accuracy: 0.8890 - val_loss: 0.7633 - val_accuracy: 0.7975
# Epoch 154/300
# 311/311 - 3s - loss: 0.3677 - accuracy: 0.8894 - val_loss: 0.7840 - val_accuracy: 0.7981
# Epoch 155/300
# 311/311 - 3s - loss: 0.3681 - accuracy: 0.8894 - val_loss: 0.7726 - val_accuracy: 0.7978
# Epoch 156/300
# 311/311 - 3s - loss: 0.3644 - accuracy: 0.8910 - val_loss: 0.7708 - val_accuracy: 0.7957
# Epoch 157/300
# 311/311 - 3s - loss: 0.3668 - accuracy: 0.8896 - val_loss: 0.7655 - val_accuracy: 0.7965
# Epoch 158/300
# 311/311 - 3s - loss: 0.3651 - accuracy: 0.8905 - val_loss: 0.7644 - val_accuracy: 0.7960
# Epoch 159/300
# 311/311 - 3s - loss: 0.3645 - accuracy: 0.8907 - val_loss: 0.7633 - val_accuracy: 0.7959
# Epoch 160/300
# 311/311 - 3s - loss: 0.3633 - accuracy: 0.8914 - val_loss: 0.7698 - val_accuracy: 0.7949
# Epoch 161/300
# 311/311 - 3s - loss: 0.3707 - accuracy: 0.8875 - val_loss: 0.7722 - val_accuracy: 0.7967
# Epoch 162/300
# 311/311 - 3s - loss: 0.3676 - accuracy: 0.8892 - val_loss: 0.7712 - val_accuracy: 0.7974
# Epoch 163/300
# 311/311 - 3s - loss: 0.3644 - accuracy: 0.8905 - val_loss: 0.7713 - val_accuracy: 0.7968
# Epoch 164/300
# 311/311 - 3s - loss: 0.3619 - accuracy: 0.8916 - val_loss: 0.7729 - val_accuracy: 0.7967
# Epoch 165/300
# 311/311 - 3s - loss: 0.3627 - accuracy: 0.8912 - val_loss: 0.7723 - val_accuracy: 0.7968
# Epoch 166/300
# 311/311 - 3s - loss: 0.3609 - accuracy: 0.8921 - val_loss: 0.7772 - val_accuracy: 0.7963
# Epoch 167/300
# 311/311 - 3s - loss: 0.3608 - accuracy: 0.8919 - val_loss: 0.7767 - val_accuracy: 0.7955
# Epoch 168/300
# 311/311 - 3s - loss: 0.3613 - accuracy: 0.8917 - val_loss: 0.7803 - val_accuracy: 0.7967
# Epoch 169/300
# 311/311 - 3s - loss: 0.3627 - accuracy: 0.8909 - val_loss: 0.7833 - val_accuracy: 0.7948
# Epoch 170/300
# 311/311 - 3s - loss: 0.3645 - accuracy: 0.8901 - val_loss: 0.7864 - val_accuracy: 0.7943
# Epoch 171/300
# 311/311 - 3s - loss: 0.3620 - accuracy: 0.8910 - val_loss: 0.7857 - val_accuracy: 0.7955
# Epoch 172/300
# 311/311 - 3s - loss: 0.3605 - accuracy: 0.8921 - val_loss: 0.7872 - val_accuracy: 0.7954
# Epoch 173/300
# 311/311 - 3s - loss: 0.3600 - accuracy: 0.8922 - val_loss: 0.7858 - val_accuracy: 0.7942
# Epoch 174/300
# 311/311 - 3s - loss: 0.3554 - accuracy: 0.8938 - val_loss: 0.8038 - val_accuracy: 0.7952
# Epoch 198/300
# 311/311 - 3s - loss: 0.3551 - accuracy: 0.8937 - val_loss: 0.8128 - val_accuracy: 0.7943
# Epoch 199/300
# 311/311 - 3s - loss: 0.3565 - accuracy: 0.8928 - val_loss: 0.8096 - val_accuracy: 0.7938
# Epoch 200/300
# 311/311 - 3s - loss: 0.3593 - accuracy: 0.8921 - val_loss: 0.8103 - val_accuracy: 0.7954
# Epoch 201/300
# 311/311 - 3s - loss: 0.3598 - accuracy: 0.8914 - val_loss: 0.8013 - val_accuracy: 0.7934
# Epoch 202/300
# 311/311 - 3s - loss: 0.3571 - accuracy: 0.8927 - val_loss: 0.8061 - val_accuracy: 0.7936
# Epoch 203/300
# 311/311 - 3s - loss: 0.3555 - accuracy: 0.8933 - val_loss: 0.8046 - val_accuracy: 0.7937
# Epoch 204/300
# 311/311 - 3s - loss: 0.3561 - accuracy: 0.8930 - val_loss: 0.8071 - val_accuracy: 0.7940
# Epoch 205/300
# 311/311 - 3s - loss: 0.3549 - accuracy: 0.8933 - val_loss: 0.8082 - val_accuracy: 0.7931
# Epoch 206/300
# 311/311 - 3s - loss: 0.3547 - accuracy: 0.8936 - val_loss: 0.8079 - val_accuracy: 0.7934
# Epoch 207/300
# 311/311 - 3s - loss: 0.3539 - accuracy: 0.8943 - val_loss: 0.8198 - val_accuracy: 0.7916
# Epoch 208/300
# 311/311 - 3s - loss: 0.3551 - accuracy: 0.8934 - val_loss: 0.8175 - val_accuracy: 0.7911
# Epoch 209/300
# 311/311 - 3s - loss: 0.3581 - accuracy: 0.8922 - val_loss: 0.8165 - val_accuracy: 0.7895
# Epoch 210/300
# 311/311 - 3s - loss: 0.3572 - accuracy: 0.8924 - val_loss: 0.8103 - val_accuracy: 0.7900
# Epoch 211/300
# 311/311 - 3s - loss: 0.3572 - accuracy: 0.8926 - val_loss: 0.8111 - val_accuracy: 0.7932
# Epoch 212/300
# 311/311 - 3s - loss: 0.3557 - accuracy: 0.8930 - val_loss: 0.8040 - val_accuracy: 0.7912
# Epoch 213/300
# 311/311 - 3s - loss: 0.3598 - accuracy: 0.8913 - val_loss: 0.8031 - val_accuracy: 0.7917
# Epoch 214/300
# 311/311 - 3s - loss: 0.3576 - accuracy: 0.8921 - val_loss: 0.8054 - val_accuracy: 0.7933
# Epoch 215/300
# 311/311 - 3s - loss: 0.3544 - accuracy: 0.8937 - val_loss: 0.8117 - val_accuracy: 0.7933
# Epoch 216/300
# 311/311 - 3s - loss: 0.3533 - accuracy: 0.8942 - val_loss: 0.8145 - val_accuracy: 0.7919
# Epoch 217/300
# 311/311 - 3s - loss: 0.3546 - accuracy: 0.8936 - val_loss: 0.8111 - val_accuracy: 0.7921
# Epoch 218/300
# 311/311 - 3s - loss: 0.3539 - accuracy: 0.8939 - val_loss: 0.8165 - val_accuracy: 0.7925
# Epoch 219/300
# 311/311 - 3s - loss: 0.3535 - accuracy: 0.8939 - val_loss: 0.8192 - val_accuracy: 0.7930
# Epoch 220/300
# 311/311 - 3s - loss: 0.3539 - accuracy: 0.8936 - val_loss: 0.8165 - val_accuracy: 0.7920
# Epoch 221/300
# 311/311 - 3s - loss: 0.3580 - accuracy: 0.8918 - val_loss: 0.8173 - val_accuracy: 0.7927
# Epoch 222/300
# 311/311 - 3s - loss: 0.3550 - accuracy: 0.8930 - val_loss: 0.8137 - val_accuracy: 0.7916
# Epoch 223/300
# 311/311 - 3s - loss: 0.3547 - accuracy: 0.8931 - val_loss: 0.8167 - val_accuracy: 0.7932
# Epoch 224/300
# 311/311 - 3s - loss: 0.3538 - accuracy: 0.8936 - val_loss: 0.8172 - val_accuracy: 0.7932
# Epoch 225/300
# 311/311 - 3s - loss: 0.3541 - accuracy: 0.8933 - val_loss: 0.8303 - val_accuracy: 0.7904
# Epoch 226/300
# 311/311 - 3s - loss: 0.3536 - accuracy: 0.8935 - val_loss: 0.8231 - val_accuracy: 0.7916
# Epoch 227/300
# 311/311 - 3s - loss: 0.3531 - accuracy: 0.8940 - val_loss: 0.8307 - val_accuracy: 0.7916
# Epoch 228/300
# 311/311 - 3s - loss: 0.3523 - accuracy: 0.8943 - val_loss: 0.8271 - val_accuracy: 0.7920
# Epoch 229/300
# 311/311 - 3s - loss: 0.3521 - accuracy: 0.8945 - val_loss: 0.8285 - val_accuracy: 0.7923
# Epoch 230/300
# 311/311 - 3s - loss: 0.3520 - accuracy: 0.8944 - val_loss: 0.8373 - val_accuracy: 0.7899
# Epoch 231/300
# 311/311 - 3s - loss: 0.3532 - accuracy: 0.8935 - val_loss: 0.8320 - val_accuracy: 0.7897
# Epoch 232/300
# 311/311 - 3s - loss: 0.3518 - accuracy: 0.8946 - val_loss: 0.8285 - val_accuracy: 0.7911
# Epoch 233/300
# 311/311 - 3s - loss: 0.3524 - accuracy: 0.8941 - val_loss: 0.8355 - val_accuracy: 0.7915
# Epoch 234/300
# 311/311 - 3s - loss: 0.3531 - accuracy: 0.8940 - val_loss: 0.8412 - val_accuracy: 0.7910
# Epoch 235/300
# 311/311 - 3s - loss: 0.3542 - accuracy: 0.8931 - val_loss: 0.8373 - val_accuracy: 0.7924
# Epoch 236/300
# 311/311 - 3s - loss: 0.3536 - accuracy: 0.8934 - val_loss: 0.8355 - val_accuracy: 0.7900
# Epoch 237/300
# 311/311 - 3s - loss: 0.3531 - accuracy: 0.8935 - val_loss: 0.8288 - val_accuracy: 0.7920
# Epoch 238/300
# 311/311 - 3s - loss: 0.3532 - accuracy: 0.8936 - val_loss: 0.8300 - val_accuracy: 0.7899
# Epoch 239/300
# 311/311 - 3s - loss: 0.3515 - accuracy: 0.8945 - val_loss: 0.8353 - val_accuracy: 0.7917
# Epoch 240/300
# 311/311 - 3s - loss: 0.3515 - accuracy: 0.8946 - val_loss: 0.8433 - val_accuracy: 0.7922
# Epoch 241/300
# 311/311 - 3s - loss: 0.3540 - accuracy: 0.8930 - val_loss: 0.8309 - val_accuracy: 0.7906
# Epoch 242/300
# 311/311 - 3s - loss: 0.3536 - accuracy: 0.8933 - val_loss: 0.8427 - val_accuracy: 0.7877
# Epoch 243/300
# 311/311 - 3s - loss: 0.3548 - accuracy: 0.8927 - val_loss: 0.8336 - val_accuracy: 0.7894
# Epoch 244/300
# 311/311 - 3s - loss: 0.3522 - accuracy: 0.8939 - val_loss: 0.8317 - val_accuracy: 0.7900
# Epoch 245/300
# 311/311 - 3s - loss: 0.3509 - accuracy: 0.8946 - val_loss: 0.8316 - val_accuracy: 0.7912
# Epoch 246/300
# 311/311 - 3s - loss: 0.3504 - accuracy: 0.8948 - val_loss: 0.8397 - val_accuracy: 0.7907
# Epoch 247/300
# 311/311 - 3s - loss: 0.3507 - accuracy: 0.8947 - val_loss: 0.8432 - val_accuracy: 0.7911
# Epoch 248/300
# 311/311 - 3s - loss: 0.3500 - accuracy: 0.8950 - val_loss: 0.8429 - val_accuracy: 0.7911
# Epoch 249/300
# 311/311 - 3s - loss: 0.3504 - accuracy: 0.8948 - val_loss: 0.8411 - val_accuracy: 0.7903
# Epoch 250/300
# 311/311 - 3s - loss: 0.3510 - accuracy: 0.8943 - val_loss: 0.8488 - val_accuracy: 0.7903
# Epoch 251/300
# 311/311 - 3s - loss: 0.3522 - accuracy: 0.8938 - val_loss: 0.8518 - val_accuracy: 0.7891
# Epoch 252/300
# 311/311 - 3s - loss: 0.3577 - accuracy: 0.8912 - val_loss: 0.8375 - val_accuracy: 0.7905
# Epoch 253/300
# 311/311 - 3s - loss: 0.3538 - accuracy: 0.8928 - val_loss: 0.8265 - val_accuracy: 0.7913
# Epoch 254/300
# 311/311 - 3s - loss: 0.3527 - accuracy: 0.8934 - val_loss: 0.8384 - val_accuracy: 0.7905
# Epoch 255/300
# 311/311 - 3s - loss: 0.3518 - accuracy: 0.8940 - val_loss: 0.8423 - val_accuracy: 0.7901
# Epoch 256/300
# 311/311 - 3s - loss: 0.3507 - accuracy: 0.8945 - val_loss: 0.8405 - val_accuracy: 0.7895
# Epoch 257/300
# 311/311 - 3s - loss: 0.3498 - accuracy: 0.8949 - val_loss: 0.8412 - val_accuracy: 0.7893
# Epoch 258/300
# 311/311 - 3s - loss: 0.3499 - accuracy: 0.8946 - val_loss: 0.8472 - val_accuracy: 0.7887
# Epoch 259/300
# 311/311 - 3s - loss: 0.3498 - accuracy: 0.8949 - val_loss: 0.8488 - val_accuracy: 0.7893
# Epoch 260/300
# 311/311 - 3s - loss: 0.3499 - accuracy: 0.8948 - val_loss: 0.8465 - val_accuracy: 0.7885
# Epoch 261/300
# 311/311 - 3s - loss: 0.3493 - accuracy: 0.8950 - val_loss: 0.8486 - val_accuracy: 0.7893
# Epoch 262/300
# 311/311 - 3s - loss: 0.3499 - accuracy: 0.8948 - val_loss: 0.8457 - val_accuracy: 0.7897
# Epoch 263/300
# 311/311 - 3s - loss: 0.3497 - accuracy: 0.8947 - val_loss: 0.8469 - val_accuracy: 0.7889
# Epoch 264/300
# 311/311 - 3s - loss: 0.3503 - accuracy: 0.8946 - val_loss: 0.8545 - val_accuracy: 0.7898
# Epoch 265/300
# 311/311 - 3s - loss: 0.3502 - accuracy: 0.8947 - val_loss: 0.8491 - val_accuracy: 0.7894
# Epoch 266/300
# 311/311 - 3s - loss: 0.3497 - accuracy: 0.8949 - val_loss: 0.8473 - val_accuracy: 0.7890
# Epoch 267/300
# 311/311 - 3s - loss: 0.3496 - accuracy: 0.8949 - val_loss: 0.8560 - val_accuracy: 0.7880
# Epoch 268/300
# 311/311 - 3s - loss: 0.3487 - accuracy: 0.8954 - val_loss: 0.8554 - val_accuracy: 0.7888
# Epoch 269/300
# 311/311 - 3s - loss: 0.3507 - accuracy: 0.8944 - val_loss: 0.8568 - val_accuracy: 0.7890
# Epoch 270/300
# 311/311 - 3s - loss: 0.3498 - accuracy: 0.8946 - val_loss: 0.8529 - val_accuracy: 0.7877
# Epoch 271/300
# 311/311 - 3s - loss: 0.3487 - accuracy: 0.8952 - val_loss: 0.8551 - val_accuracy: 0.7890
# Epoch 272/300
# 311/311 - 3s - loss: 0.3492 - accuracy: 0.8950 - val_loss: 0.8546 - val_accuracy: 0.7887
# Epoch 273/300
# 311/311 - 3s - loss: 0.3506 - accuracy: 0.8942 - val_loss: 0.8678 - val_accuracy: 0.7887
# Epoch 274/300
# 311/311 - 3s - loss: 0.3527 - accuracy: 0.8934 - val_loss: 0.8673 - val_accuracy: 0.7884
# Epoch 275/300
# 311/311 - 3s - loss: 0.3533 - accuracy: 0.8931 - val_loss: 0.8473 - val_accuracy: 0.7886
# Epoch 276/300
# 311/311 - 3s - loss: 0.3510 - accuracy: 0.8941 - val_loss: 0.8473 - val_accuracy: 0.7907
# Epoch 277/300
# 311/311 - 3s - loss: 0.3506 - accuracy: 0.8942 - val_loss: 0.8551 - val_accuracy: 0.7882
# Epoch 278/300
# 311/311 - 3s - loss: 0.3500 - accuracy: 0.8946 - val_loss: 0.8497 - val_accuracy: 0.7888
# Epoch 279/300
# 311/311 - 3s - loss: 0.3491 - accuracy: 0.8950 - val_loss: 0.8612 - val_accuracy: 0.7877
# Epoch 280/300
# 311/311 - 3s - loss: 0.3491 - accuracy: 0.8948 - val_loss: 0.8582 - val_accuracy: 0.7888
# Epoch 281/300
# 311/311 - 3s - loss: 0.3484 - accuracy: 0.8953 - val_loss: 0.8562 - val_accuracy: 0.7873
# Epoch 282/300
# 311/311 - 3s - loss: 0.3479 - accuracy: 0.8955 - val_loss: 0.8586 - val_accuracy: 0.7877
# Epoch 283/300
# 311/311 - 3s - loss: 0.3474 - accuracy: 0.8957 - val_loss: 0.8597 - val_accuracy: 0.7882
# Epoch 284/300
# 311/311 - 3s - loss: 0.3477 - accuracy: 0.8955 - val_loss: 0.8611 - val_accuracy: 0.7869
# Epoch 285/300
# 311/311 - 3s - loss: 0.3475 - accuracy: 0.8956 - val_loss: 0.8634 - val_accuracy: 0.7865
# Epoch 286/300
# 311/311 - 3s - loss: 0.3471 - accuracy: 0.8960 - val_loss: 0.8666 - val_accuracy: 0.7872
# Epoch 287/300
# 311/311 - 3s - loss: 0.3467 - accuracy: 0.8960 - val_loss: 0.8688 - val_accuracy: 0.7861
# Epoch 288/300
# 311/311 - 3s - loss: 0.3469 - accuracy: 0.8959 - val_loss: 0.8720 - val_accuracy: 0.7873
# Epoch 289/300
# 311/311 - 3s - loss: 0.3465 - accuracy: 0.8961 - val_loss: 0.8698 - val_accuracy: 0.7865
# Epoch 290/300
# 311/311 - 3s - loss: 0.3467 - accuracy: 0.8960 - val_loss: 0.8712 - val_accuracy: 0.7869
# Epoch 291/300
# 311/311 - 3s - loss: 0.3465 - accuracy: 0.8961 - val_loss: 0.8722 - val_accuracy: 0.7851
# Epoch 292/300
# 311/311 - 3s - loss: 0.3487 - accuracy: 0.8951 - val_loss: 0.8741 - val_accuracy: 0.7860
# Epoch 293/300
# 311/311 - 3s - loss: 0.3482 - accuracy: 0.8950 - val_loss: 0.8741 - val_accuracy: 0.7863
# Epoch 294/300
# 311/311 - 3s - loss: 0.3478 - accuracy: 0.8952 - val_loss: 0.8705 - val_accuracy: 0.7857
# Epoch 295/300
# 311/311 - 3s - loss: 0.3473 - accuracy: 0.8957 - val_loss: 0.8729 - val_accuracy: 0.7865
# Epoch 296/300
# 311/311 - 3s - loss: 0.3476 - accuracy: 0.8954 - val_loss: 0.8707 - val_accuracy: 0.7862
# Epoch 297/300
# 311/311 - 3s - loss: 0.3471 - accuracy: 0.8957 - val_loss: 0.8733 - val_accuracy: 0.7869
# Epoch 298/300
# 311/311 - 3s - loss: 0.3469 - accuracy: 0.8956 - val_loss: 0.8776 - val_accuracy: 0.7861
# Epoch 299/300
# 311/311 - 3s - loss: 0.3497 - accuracy: 0.8945 - val_loss: 0.8811 - val_accuracy: 0.7859
# Epoch 300/300
# 311/311 - 3s - loss: 0.3505 - accuracy: 0.8940 - val_loss: 0.8689 - val_accuracy: 0.7868

# %%
#save the weights
model32.save("model32.h5")
print("model saved")
# Out:
# model saved

# %% [markdown]
# # test: prediction and visual

# %%
#get test part of dataset

def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        # 1 means input a colored images, while 0 or 2 represent grayscale image. other numbers will get the colored output
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):    
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

dir_test_seg = "/content/Colab Notebooks/dataset1/annotations_prepped_test/"# annotations_prepped_train   Don't forget to write "." in front of /
dir_test_img = "/content/Colab Notebooks/dataset1/images_prepped_test/"# images_prepped_train
  
test_images = os.listdir(dir_test_img)
test_images.sort()#sort it
test_segmentations  = os.listdir(dir_test_seg)
test_segmentations.sort()
    
imgs = []
segs = []
input_width=224
input_height=224
output_width=224
output_height=224

for im , seg in zip(test_images,test_segmentations) :#zip is generator and returns to list[(),(),......],im and seg here are the names of images
    imgs.append( getImageArr(dir_test_img +"/"+ im , input_width , input_height )  )
    segs.append( getSegmentationArr( dir_test_seg +"/"+ seg , n_classes , output_width , output_height )  )

imgs, segs = np.array(imgs) , np.array(segs)
print(imgs.shape,segs.shape)
# Out:
# (101, 224, 224, 3) (101, 224, 224, 12)

# %%
#make predictions by keras.Model.predicit
predictions=model32.predict(imgs, batch_size=None)
#print(predictions.shape) -> output:(101,224,224,12)

#make it to be 1 or 0
predictions=(predictions+0.5).astype(int)

# %%
#functions for visualize
import numpy as np
def give_color_to_seg_img(seg,n_classes):
    seg_img=np.zeros(seg.shape) #note:seg is a 3_dimension image!!
    for i in range(n_classes):
        indexh=np.where(seg==i)[0]
        indexw=np.where(seg==i)[1]
        seg_img[indexh,indexw,:]= sns.color_palette("hls", n_classes)[i]
    return(seg_img)
def visualize(output):#a function converts 12-dimension to 3-dimension; values changed from 0/1 to 0-11
    img=np.zeros((224,224,3))
    for i in range (224):
        for j in range(224):
            index=np.where(output[i,j,:]==np.max(output[i,j,:]))[0][0]
            img[i,j,:]=index
    seg_img = give_color_to_seg_img(img,n_classes).astype(np.float)#image should be 3-dimension input
    plt.imshow(seg_img)
def choose_a_images_to_compare(num):#input index of images
    
    plt.imshow(((imgs[num]+1)*127.5).astype(np.int32))
    plt.title(str(num+1)+'th image')
    plt.show()

    #annotations_prepped_test
    plt.subplot(1,2,1)
    visualize(segs[num])
    plt.title(str(num+1)+'th ground truth')
    plt.subplot(1,2,2)
    visualize(predictions[num])
    plt.title(str(num+1)+'th segmentation')
    plt.show()

# %%
#call the function
choose_a_images_to_compare(0)

#intersection = np.logical_and(segs, predictions)
#union = np.logical_or(segs, predictions)
#iou_score = np.sum(intersection) / np.sum(union)
#print('mIoU for all test images',iou_score)

# %% [markdown]
# #Doctor's metric to test

# %%
#convert predictions to 3-d type
def convert_12d_to_3d(output):
  img=np.zeros((224,224,3))
  for i in range (224):
      for j in range(224):
          index=np.where(output[i,j,:]==np.max(output[i,j,:]))[0][0]
          img[i,j,:]=index
  return img
def convert_12d_dataset_to_3d(predictions):
  predictions_tem=np.zeros((predictions.shape[0],predictions.shape[1],predictions.shape[2],3))
  for i in range(predictions.shape[0]):
    predictions_tem[i]=convert_12d_to_3d(predictions[i])
  return predictions_tem

#predictions_tem is 3-d type of predictions, ranging from 0 to 11

# %%
Yi=convert_12d_dataset_to_3d(segs)
y_predi=convert_12d_dataset_to_3d(predictions)

# %%
print('Yi.shape:',Yi.shape)
print('y_predi.shape:',y_predi.shape)
# Out:
# Yi.shape: (101, 224, 224, 3)
# y_predi.shape: (101, 224, 224, 3)

# %%
def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))
    
IoU(Yi,y_predi)
# Out:
# class 00: #TP=1297749, #FP=1370883, #FN=70170, IoU=0.474
# class 01: #TP=2966013, #FP=1851090, #FN=945825, IoU=0.515
# class 02: #TP=   192, #FP= 24849, #FN=109068, IoU=0.001
# class 03: #TP=4114464, #FP=254334, #FN=310593, IoU=0.879
# class 04: #TP=1063866, #FP=309558, #FN=281433, IoU=0.643
# class 05: #TP=865386, #FP=147411, #FN=1614249, IoU=0.329
# class 06: #TP=  5508, #FP= 25926, #FN=154668, IoU=0.030
# class 07: #TP= 16203, #FP=122925, #FN=453006, IoU=0.027
# class 08: #TP=164964, #FP=454485, #FN=117216, IoU=0.224
# class 09: #TP=   255, #FP= 65286, #FN=110340, IoU=0.001
# class 10: #TP=  1635, #FP= 11502, #FN=331281, IoU=0.005
# class 11: #TP= 13467, #FP= 55377, #FN=195777, IoU=0.051
# _________________
# Mean IoU: 0.265
