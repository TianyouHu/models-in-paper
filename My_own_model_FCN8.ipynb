# %% [markdown]
# ### code to upload files which are not folders in colab

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-0f5f8cac-5f10-4dff-ab40-5f39e6a28126" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f5f8cac-5f10-4dff-ab40-5f39e6a28126">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pepsi.jpg to pepsi.jpg

# %% [markdown]
# ### code to upload folder

# %%
from google.colab import drive#drive means google drive
drive.mount('/content/drive/')#this is the default directory of google drive
#Go to URL in browser is to make sure I'm the owner of the account
#After this section the drive files has been upload
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ln -s "/content/drive/My Drive/Colab Notebooks/" "/content/"
#Someone on the internet says move the folder into another path 
#which is not "drive" can speed up the code

# %% [markdown]
# # Fully Convolutional Networks for semantic segmentation
#
# In an image for the semantic segmentation, each pixcel is labeled with the class of its enclosing object. The semantic segmentation problem requires to make a classification at every pixel.
#
# First, download data from:
#
# https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view
#
# and save the downloaded data folder in the current directory.

# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid", {'axes.grid' : False})
# enter your path here
dir_seg = "/content/Colab Notebooks/dataset1/annotations_prepped_train/"# annotations_prepped_train   Don't forget to write "." in front of /
dir_img = "/content/Colab Notebooks/dataset1/images_prepped_train/"# images_prepped_train

ldseg = np.array(os.listdir(dir_seg))

## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
## Read first image from annotations_prepped_train and images_prepped_train with path "dir_seg +"/"+ fnm"
#if using imread here, seg will be 2-dimension instead of 3-dimension
seg = cv2.imread(dir_seg  +"/"+ fnm ) # image from annotations_prepped_train (360, 480, 3)
img_is = cv2.imread(dir_img  +"/"+ fnm )# image from images_prepped_train
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma-mi+1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

# Plot original image from images_prepped_train image:
plt.imshow(img_is)
# Plot all class from annotations_prepped_train image:
fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8a21e360b598> in <module>
#       9 dir_img = "/content/Colab Notebooks/dataset1/images_prepped_train/"# images_prepped_train
#      10
# ---> 11 ldseg = np.array(os.listdir(dir_seg))
#      12
#      13 ## pick the first image file
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: '/content/Colab Notebooks/dataset1/annotations_prepped_train/'

# %% [markdown]
# From the first section, we can see there are 12 segmentation classes and the image is from a driving car.
#
# Assign color to annotations_prepped_train image

# %%
import random
def give_color_to_seg_img(seg,n_classes):
    seg_img=np.zeros(seg.shape) #note:seg is a 3_dimension image!!
    for i in range(n_classes):
        indexh=np.where(seg==i)[0]
        indexw=np.where(seg==i)[1]
        seg_img[indexh,indexw,:]= sns.color_palette("hls", n_classes)[i]
    return(seg_img)

input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    #np.random.choice() choose random number from [0,len(ldseg)), returns to a array. 3 is size. False means cannot choose repeated numbers
    # randomly select on the training image
    fnm = fnm.split(".")[0]#get the name of original image and discard ".png"
    seg = cv2.imread(dir_seg  +"/"+ fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img  +"/"+ fnm + ".png")
    # assign color to its annotations_prepped_train image
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(output_height , output_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %% [markdown]
# To simplify the problem, I will reshape all the images to the same size: (224,224).
#
# Since this is the image shape used in VGG and FCN model in this blog uses a network that takes advantage of VGG structure. The FCN model becomes easier to explain when the image shape is (224,224).

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        # 1 means input a colored images, while 0 or 2 represent grayscale image. other numbers will get the colored output
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):    
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

  
images = os.listdir(dir_img)
images.sort()#sort it
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :#zip is generator and returns to list[(),(),......],im and seg here are the names of images
    X.append( getImageArr(dir_img +"/"+ im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg +"/"+ seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
#X,Y are arrays. There shapes are down below. 367 images in total; So X,Y contains all the trained original images and annotation images
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %% [markdown]
# Import Keras and Tensorflow to develop deep learning FCN models

# %%
## Import usual libraries
import tensorflow as tf
from tensorflow.python.keras.backend import set_session#this sentence is changed 
#or it will raise errors : No module named 'keras.backend.tensorflow_backend'; 'keras.backend' is not a package
import keras, sys, time, warnings
from tensorflow.python.keras.models import *#these 2 sentence are changed to make Input() works later
from tensorflow.python.keras.layers import *

tf.compat.v1.disable_eager_execution()

import pandas as pd 
warnings.filterwarnings("ignore")

###############################################
  
# check python, keras, and tensorflow version
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras# del delete the variables
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.6.9 (default, Jul 17 2020, 12:50:27)
# [GCC 8.4.0]
# keras version 2.4.3
# tensorflow version 2.3.0

# %% [markdown]
# # From classifier to dense FCN
# The recent successful deep learning models such as VGG are originally designed for classification task. The network stacks convolution layers together with down-sampling layers, such as max-pooling, and then finally stacks fully connected layers. Appending a fully connected layer enables the network to learn something using global information where the spatial arrangement of the input falls away.
#
# # Fully convolutional network
# For the segmentation task, however, spatial infomation should be stored to make a pixel-wise classification. FCN allows this by making all the layers of VGG to convolutional layers.
#
# Fully convolutional indicates that the neural network is composed of convolutional layers without any fully-connected layers usually found at the end of the network. Fully Convolutional Networks for Semantic Segmentation motivates the use of fully convolutional networks by "convolutionalizing" popular CNN architectures e.g. VGG can also be viewed as FCN.
#
# The following method is FCN8 from Fully Convolutional Networks for Semantic Segmentation. It deplicates VGG16 net by discarding the final classifier layer and convert all fully connected layers to convolutions. Output image size is (output_height, output_width) = (224,224).
#
# # Upsampling
# The upsampling layer brings low resolution image to high resolution. There are various upsamping methods. This presentation gives a good overview. For example, one may double the image resolution by duplicating each pixcel twice. This is so-called nearest neighbor approach and implemented in Keras's UpSampling2D.
#
# These upsampling layers do not have weights/parameters so the model is not flexible. Instead, FCN8 uses upsampling procedure called backwards convolusion (sometimes called deconvolution) with output stride. This method simply reverses the forward and backward passes of convolution and implemented in Keras's Conv2DTranspose.
#
# In FCN8, the upsampling layer is followed by several skip connections. See details at Fully Convolutional Networks for Semantic Segmentation.
#
# Downloaded VGG16 weights from fchollet's Github:
# https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
#
# This is a massive .h5 file (57MB).

# %%
# location of weights
VGG_Weights_path = "/content/Colab Notebooks/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5" 
fcn8_weights_path="/content/Colab Notebooks/model8.h5"

# %% [markdown]
# ## FCN8
# ### code down below is about FCN8

# %%
def FCN8( nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,  
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 
    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    #actually the shape of tf.python.keras.layers.Input is [batch_size,224,224,3], batch_size is None here.
    
    # Block 1  default: using bias
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x1)
    x1 = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x1)

    # Block 2
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x1)
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x2)
    x2 = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x2)
    # Block 3
    x3 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x2)
    x3 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x3)
    x3 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x3)
    x3 = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x3)
    # Block 4
    x4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x3)
    x4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x4)
    x4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x4)
    x4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x4)
    # Block 5
    x5 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(x4)
    x5 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x5)
    x5 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x5)
    x5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x5)#now x.shape is (batch_size,7,7,512)
    
    n = 4096
    
    x6 = Conv2D(n, (3, 3), activation='relu', padding='same', name='conv6',data_format=IMAGE_ORDERING )(x5)
    x7 = Conv2D(n_classes, (1, 1), activation='relu', padding='same',name='conv7', data_format=IMAGE_ORDERING )(x6)
    #now conv7.shape is (batchsize,7,7,4096)
    ## 4 times upsampling for cov7, 2 times upsampling pool4
    upsampled_conv7=UpSampling2D(size=(4,4),interpolation='bilinear')(x7)#shape [batchsize,28,28,12]
    pool4_tem=Conv2D(n_classes, (3, 3), activation='relu', padding='same', name='pool4_tem', data_format=IMAGE_ORDERING )(x4)
    upsampled_pool4=UpSampling2D(size=(2,2),interpolation='bilinear')(pool4_tem)
    #conv x3 to channel of 12
    pool3_tem=Conv2D(n_classes, (3, 3), activation='relu', padding='same', name='pool3_tem', data_format=IMAGE_ORDERING )(x3)
    
    #combine the upsampling and softmax
    fuse=Add()([upsampled_conv7,upsampled_pool4,pool3_tem])
    upsample_8=UpSampling2D(size=(8,8),interpolation='bilinear')(fuse)
    prediction=Softmax(axis=-1)(upsample_8)
    #output image shape
    # create model and load weight
    model=Model(inputs=img_input,outputs=prediction)
    

    return model
model8 = FCN8(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)

model8.load_weights(fcn8_weights_path, by_name=True)
#don't load_weights or the max accuracy will decline

model8.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 7, 7, 4096)   18878464    block5_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 7, 7, 12)     49164       conv6[0][0]
# __________________________________________________________________________________________________
# pool4_tem (Conv2D)              (None, 14, 14, 12)   55308       block4_pool[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 28, 28, 12)   0           conv7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 12)   0           pool4_tem[0][0]
# __________________________________________________________________________________________________
# pool3_tem (Conv2D)              (None, 28, 28, 12)   27660       block3_pool[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 12)   0           up_sampling2d[0][0]
#                                                                  up_sampling2d_1[0][0]
#                                                                  pool3_tem[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 12) 0           add[0][0]
# __________________________________________________________________________________________________
# softmax (Softmax)               (None, 224, 224, 12) 0           up_sampling2d_2[0][0]
# ==================================================================================================
# Total params: 33,725,284
# Trainable params: 33,725,284
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Split between training and testing data

# %%
from sklearn.utils import shuffle
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)#array which has "number of images*train rate" elements
index_test  = list(set(range(X.shape[0])) - set(index_train))#return to a list containing all the test index
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# # Train the model
# ##I trained 300 epochs

# %%
from tensorflow.python.keras import optimizers# keras is not tensorflow.python.keras. This sentence should be the same as the one before


# Training data
sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model8.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model8.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=150,verbose=2)#this sentence feed data to the model,
                                                   #the sentences before it just create the model with specific dimension and shape(structure)
    #default batch size=32
# Out:
# Train on 311 samples, validate on 56 samples
# Epoch 1/150
# 311/311 - 4s - loss: 2.4019 - accuracy: 0.2915 - val_loss: 2.2178 - val_accuracy: 0.3063
# Epoch 2/150
# 311/311 - 3s - loss: 1.9895 - accuracy: 0.3940 - val_loss: 1.6935 - val_accuracy: 0.4841
# Epoch 3/150
# 311/311 - 3s - loss: 1.5454 - accuracy: 0.5510 - val_loss: 1.6984 - val_accuracy: 0.4811
# Epoch 4/150
# 311/311 - 3s - loss: 1.4937 - accuracy: 0.5377 - val_loss: 1.3408 - val_accuracy: 0.5993
# Epoch 5/150
# 311/311 - 3s - loss: 1.2590 - accuracy: 0.6295 - val_loss: 1.2131 - val_accuracy: 0.6501
# Epoch 6/150
# 311/311 - 3s - loss: 1.1626 - accuracy: 0.6538 - val_loss: 1.1160 - val_accuracy: 0.6679
# Epoch 7/150
# 311/311 - 3s - loss: 1.1142 - accuracy: 0.6608 - val_loss: 1.0626 - val_accuracy: 0.6806
# Epoch 8/150
# 311/311 - 3s - loss: 1.0833 - accuracy: 0.6667 - val_loss: 1.0470 - val_accuracy: 0.6869
# Epoch 9/150
# 311/311 - 3s - loss: 1.0279 - accuracy: 0.6779 - val_loss: 0.9738 - val_accuracy: 0.6962
# Epoch 10/150
# 311/311 - 3s - loss: 1.0130 - accuracy: 0.6809 - val_loss: 0.9811 - val_accuracy: 0.6930
# Epoch 11/150
# 311/311 - 3s - loss: 0.9833 - accuracy: 0.6862 - val_loss: 0.9349 - val_accuracy: 0.7084
# Epoch 12/150
# 311/311 - 3s - loss: 0.9900 - accuracy: 0.6808 - val_loss: 0.9391 - val_accuracy: 0.7025
# Epoch 13/150
# 311/311 - 3s - loss: 0.9640 - accuracy: 0.6905 - val_loss: 0.9349 - val_accuracy: 0.7060
# Epoch 14/150
# 311/311 - 3s - loss: 0.9607 - accuracy: 0.6926 - val_loss: 0.9120 - val_accuracy: 0.7131
# Epoch 15/150
# 311/311 - 3s - loss: 0.9292 - accuracy: 0.7002 - val_loss: 0.8963 - val_accuracy: 0.7087
# Epoch 16/150
# 311/311 - 3s - loss: 0.9405 - accuracy: 0.6960 - val_loss: 0.8833 - val_accuracy: 0.7110
# Epoch 17/150
# 311/311 - 3s - loss: 0.9025 - accuracy: 0.7073 - val_loss: 0.9154 - val_accuracy: 0.6851
# Epoch 18/150
# 311/311 - 3s - loss: 0.9178 - accuracy: 0.6991 - val_loss: 0.8688 - val_accuracy: 0.7258
# Epoch 19/150
# 311/311 - 3s - loss: 0.9066 - accuracy: 0.7104 - val_loss: 0.8478 - val_accuracy: 0.7294
# Epoch 20/150
# 311/311 - 3s - loss: 0.8852 - accuracy: 0.7162 - val_loss: 0.8884 - val_accuracy: 0.7048
# Epoch 21/150
# 311/311 - 3s - loss: 0.8885 - accuracy: 0.7144 - val_loss: 0.8312 - val_accuracy: 0.7409
# Epoch 22/150
# 311/311 - 3s - loss: 0.8804 - accuracy: 0.7190 - val_loss: 0.8199 - val_accuracy: 0.7345
# Epoch 23/150
# 311/311 - 3s - loss: 0.8703 - accuracy: 0.7234 - val_loss: 0.8089 - val_accuracy: 0.7497
# Epoch 24/150
# 311/311 - 3s - loss: 0.8512 - accuracy: 0.7318 - val_loss: 0.8743 - val_accuracy: 0.7017
# Epoch 25/150
# 311/311 - 3s - loss: 0.8417 - accuracy: 0.7372 - val_loss: 0.7840 - val_accuracy: 0.7568
# Epoch 26/150
# 311/311 - 3s - loss: 0.8603 - accuracy: 0.7278 - val_loss: 0.8494 - val_accuracy: 0.7184
# Epoch 27/150
# 311/311 - 3s - loss: 0.8357 - accuracy: 0.7413 - val_loss: 0.8044 - val_accuracy: 0.7456
# Epoch 28/150
# 311/311 - 3s - loss: 0.8400 - accuracy: 0.7341 - val_loss: 0.8239 - val_accuracy: 0.7529
# Epoch 29/150
# 311/311 - 3s - loss: 0.8150 - accuracy: 0.7506 - val_loss: 0.7498 - val_accuracy: 0.7697
# Epoch 30/150
# 311/311 - 3s - loss: 0.8284 - accuracy: 0.7403 - val_loss: 0.8078 - val_accuracy: 0.7444
# Epoch 31/150
# 311/311 - 3s - loss: 0.7977 - accuracy: 0.7560 - val_loss: 0.7358 - val_accuracy: 0.7785
# Epoch 32/150
# 311/311 - 3s - loss: 0.7996 - accuracy: 0.7525 - val_loss: 0.8912 - val_accuracy: 0.7044
# Epoch 33/150
# 311/311 - 3s - loss: 0.7880 - accuracy: 0.7589 - val_loss: 0.7267 - val_accuracy: 0.7847
# Epoch 34/150
# 311/311 - 3s - loss: 0.8030 - accuracy: 0.7490 - val_loss: 0.9083 - val_accuracy: 0.7328
# Epoch 35/150
# 311/311 - 3s - loss: 0.8260 - accuracy: 0.7475 - val_loss: 0.7363 - val_accuracy: 0.7777
# Epoch 36/150
# 311/311 - 3s - loss: 0.7661 - accuracy: 0.7685 - val_loss: 0.7684 - val_accuracy: 0.7578
# Epoch 37/150
# 311/311 - 3s - loss: 0.7783 - accuracy: 0.7597 - val_loss: 0.7279 - val_accuracy: 0.7820
# Epoch 38/150
# 311/311 - 3s - loss: 0.7716 - accuracy: 0.7640 - val_loss: 0.7859 - val_accuracy: 0.7629
# Epoch 39/150
# 311/311 - 3s - loss: 0.7653 - accuracy: 0.7706 - val_loss: 0.7206 - val_accuracy: 0.7862
# Epoch 40/150
# 311/311 - 3s - loss: 0.7497 - accuracy: 0.7728 - val_loss: 0.7502 - val_accuracy: 0.7649
# Epoch 41/150
# 311/311 - 3s - loss: 0.7851 - accuracy: 0.7600 - val_loss: 0.7024 - val_accuracy: 0.7878
# Epoch 42/150
# 311/311 - 3s - loss: 0.7386 - accuracy: 0.7770 - val_loss: 0.6773 - val_accuracy: 0.7986
# Epoch 43/150
# 311/311 - 3s - loss: 0.7241 - accuracy: 0.7814 - val_loss: 0.7144 - val_accuracy: 0.7861
# Epoch 44/150
# 311/311 - 3s - loss: 0.7480 - accuracy: 0.7704 - val_loss: 0.7011 - val_accuracy: 0.7884
# Epoch 45/150
# 311/311 - 3s - loss: 0.7163 - accuracy: 0.7829 - val_loss: 0.6963 - val_accuracy: 0.7890
# Epoch 46/150
# 311/311 - 3s - loss: 0.7213 - accuracy: 0.7823 - val_loss: 0.7135 - val_accuracy: 0.7788
# Epoch 47/150
# 311/311 - 3s - loss: 0.7225 - accuracy: 0.7809 - val_loss: 0.6577 - val_accuracy: 0.8051
# Epoch 48/150
# 311/311 - 3s - loss: 0.7030 - accuracy: 0.7892 - val_loss: 0.6478 - val_accuracy: 0.8046
# Epoch 49/150
# 311/311 - 3s - loss: 0.6999 - accuracy: 0.7887 - val_loss: 0.8729 - val_accuracy: 0.7419
# Epoch 50/150
# 311/311 - 3s - loss: 0.7501 - accuracy: 0.7749 - val_loss: 0.6566 - val_accuracy: 0.8071
# Epoch 51/150
# 311/311 - 3s - loss: 0.6847 - accuracy: 0.7969 - val_loss: 0.6511 - val_accuracy: 0.8030
# Epoch 52/150
# 311/311 - 3s - loss: 0.7219 - accuracy: 0.7818 - val_loss: 0.6439 - val_accuracy: 0.8093
# Epoch 53/150
# 311/311 - 3s - loss: 0.6863 - accuracy: 0.7944 - val_loss: 0.6300 - val_accuracy: 0.8137
# Epoch 54/150
# 311/311 - 3s - loss: 0.6735 - accuracy: 0.7997 - val_loss: 0.6359 - val_accuracy: 0.8096
# Epoch 55/150
# 311/311 - 3s - loss: 0.6918 - accuracy: 0.7911 - val_loss: 0.6669 - val_accuracy: 0.8039
# Epoch 56/150
# 311/311 - 3s - loss: 0.6715 - accuracy: 0.8005 - val_loss: 0.6291 - val_accuracy: 0.8115
# Epoch 57/150
# 311/311 - 3s - loss: 0.6780 - accuracy: 0.7960 - val_loss: 0.6815 - val_accuracy: 0.7872
# Epoch 58/150
# 311/311 - 3s - loss: 0.6637 - accuracy: 0.8023 - val_loss: 0.6330 - val_accuracy: 0.8121
# Epoch 59/150
# 311/311 - 3s - loss: 0.6668 - accuracy: 0.8008 - val_loss: 0.6208 - val_accuracy: 0.8163
# Epoch 60/150
# 311/311 - 3s - loss: 0.6468 - accuracy: 0.8079 - val_loss: 0.7166 - val_accuracy: 0.7629
# Epoch 61/150
# 311/311 - 3s - loss: 0.6702 - accuracy: 0.7985 - val_loss: 0.6076 - val_accuracy: 0.8201
# Epoch 62/150
# 311/311 - 3s - loss: 0.6688 - accuracy: 0.7989 - val_loss: 0.6210 - val_accuracy: 0.8199
# Epoch 63/150
# 311/311 - 3s - loss: 0.6456 - accuracy: 0.8084 - val_loss: 0.6021 - val_accuracy: 0.8241
# Epoch 64/150
# 311/311 - 3s - loss: 0.6345 - accuracy: 0.8109 - val_loss: 0.6679 - val_accuracy: 0.7981
# Epoch 65/150
# 311/311 - 3s - loss: 0.7044 - accuracy: 0.7851 - val_loss: 0.6144 - val_accuracy: 0.8183
# Epoch 66/150
# 311/311 - 3s - loss: 0.6429 - accuracy: 0.8084 - val_loss: 0.6040 - val_accuracy: 0.8223
# Epoch 67/150
# 311/311 - 3s - loss: 0.6341 - accuracy: 0.8121 - val_loss: 0.5988 - val_accuracy: 0.8237
# Epoch 68/150
# 311/311 - 3s - loss: 0.6290 - accuracy: 0.8130 - val_loss: 0.7595 - val_accuracy: 0.7755
# Epoch 69/150
# 311/311 - 3s - loss: 0.6766 - accuracy: 0.7974 - val_loss: 0.5932 - val_accuracy: 0.8268
# Epoch 70/150
# 311/311 - 3s - loss: 0.6223 - accuracy: 0.8158 - val_loss: 0.5977 - val_accuracy: 0.8244
# Epoch 71/150
# 311/311 - 3s - loss: 0.6540 - accuracy: 0.8036 - val_loss: 0.5918 - val_accuracy: 0.8306
# Epoch 72/150
# 311/311 - 3s - loss: 0.6230 - accuracy: 0.8155 - val_loss: 0.5921 - val_accuracy: 0.8268
# Epoch 73/150
# 311/311 - 3s - loss: 0.6125 - accuracy: 0.8194 - val_loss: 0.5970 - val_accuracy: 0.8218
# Epoch 74/150
# 311/311 - 3s - loss: 0.6406 - accuracy: 0.8074 - val_loss: 0.5803 - val_accuracy: 0.8316
# Epoch 75/150
# 311/311 - 3s - loss: 0.6074 - accuracy: 0.8196 - val_loss: 0.6101 - val_accuracy: 0.8194
# Epoch 76/150
# 311/311 - 3s - loss: 0.6355 - accuracy: 0.8099 - val_loss: 0.5865 - val_accuracy: 0.8299
# Epoch 77/150
# 311/311 - 3s - loss: 0.6073 - accuracy: 0.8211 - val_loss: 0.5759 - val_accuracy: 0.8331
# Epoch 78/150
# 311/311 - 3s - loss: 0.6003 - accuracy: 0.8238 - val_loss: 0.5719 - val_accuracy: 0.8313
# Epoch 79/150
# 311/311 - 3s - loss: 0.6377 - accuracy: 0.8087 - val_loss: 0.6495 - val_accuracy: 0.7984
# Epoch 80/150
# 311/311 - 3s - loss: 0.6080 - accuracy: 0.8201 - val_loss: 0.5745 - val_accuracy: 0.8345
# Epoch 81/150
# 311/311 - 3s - loss: 0.6097 - accuracy: 0.8187 - val_loss: 0.6369 - val_accuracy: 0.8088
# Epoch 82/150
# 311/311 - 3s - loss: 0.6153 - accuracy: 0.8173 - val_loss: 0.5749 - val_accuracy: 0.8322
# Epoch 83/150
# 311/311 - 3s - loss: 0.5957 - accuracy: 0.8234 - val_loss: 0.5920 - val_accuracy: 0.8261
# Epoch 84/150
# 311/311 - 3s - loss: 0.6029 - accuracy: 0.8220 - val_loss: 0.6096 - val_accuracy: 0.8184
# Epoch 85/150
# 311/311 - 3s - loss: 0.6222 - accuracy: 0.8128 - val_loss: 0.5659 - val_accuracy: 0.8345
# Epoch 86/150
# 311/311 - 4s - loss: 0.5880 - accuracy: 0.8259 - val_loss: 0.5547 - val_accuracy: 0.8389
# Epoch 87/150
# 311/311 - 3s - loss: 0.5973 - accuracy: 0.8217 - val_loss: 0.5620 - val_accuracy: 0.8353
# Epoch 88/150
# 311/311 - 3s - loss: 0.5855 - accuracy: 0.8279 - val_loss: 0.5781 - val_accuracy: 0.8289
# Epoch 89/150
# 311/311 - 3s - loss: 0.5893 - accuracy: 0.8261 - val_loss: 0.5880 - val_accuracy: 0.8252
# Epoch 90/150
# 311/311 - 3s - loss: 0.5934 - accuracy: 0.8234 - val_loss: 0.6483 - val_accuracy: 0.7959
# Epoch 91/150
# 311/311 - 3s - loss: 0.6038 - accuracy: 0.8192 - val_loss: 0.5582 - val_accuracy: 0.8375
# Epoch 92/150
# 311/311 - 3s - loss: 0.5715 - accuracy: 0.8322 - val_loss: 0.5494 - val_accuracy: 0.8407
# Epoch 93/150
# 311/311 - 3s - loss: 0.6112 - accuracy: 0.8174 - val_loss: 0.5619 - val_accuracy: 0.8388
# Epoch 94/150
# 311/311 - 3s - loss: 0.5716 - accuracy: 0.8319 - val_loss: 0.5484 - val_accuracy: 0.8413
# Epoch 95/150
# 311/311 - 3s - loss: 0.5873 - accuracy: 0.8267 - val_loss: 0.5778 - val_accuracy: 0.8274
# Epoch 96/150
# 311/311 - 3s - loss: 0.5632 - accuracy: 0.8346 - val_loss: 0.5584 - val_accuracy: 0.8355
# Epoch 97/150
# 311/311 - 3s - loss: 0.5807 - accuracy: 0.8274 - val_loss: 0.5505 - val_accuracy: 0.8385
# Epoch 98/150
# 311/311 - 3s - loss: 0.5650 - accuracy: 0.8333 - val_loss: 0.5433 - val_accuracy: 0.8415
# Epoch 99/150
# 311/311 - 3s - loss: 0.5851 - accuracy: 0.8249 - val_loss: 0.5949 - val_accuracy: 0.8256
# Epoch 100/150
# 311/311 - 3s - loss: 0.5706 - accuracy: 0.8314 - val_loss: 0.5430 - val_accuracy: 0.8413
# Epoch 101/150
# 311/311 - 3s - loss: 0.5623 - accuracy: 0.8342 - val_loss: 0.5419 - val_accuracy: 0.8423
# Epoch 102/150
# 311/311 - 3s - loss: 0.5843 - accuracy: 0.8247 - val_loss: 0.5356 - val_accuracy: 0.8442
# Epoch 103/150
# 311/311 - 3s - loss: 0.5616 - accuracy: 0.8343 - val_loss: 0.5399 - val_accuracy: 0.8426
# Epoch 104/150
# 311/311 - 4s - loss: 0.5616 - accuracy: 0.8355 - val_loss: 0.5381 - val_accuracy: 0.8432
# Epoch 105/150
# 311/311 - 5s - loss: 0.5508 - accuracy: 0.8384 - val_loss: 0.5527 - val_accuracy: 0.8348
# Epoch 106/150
# 311/311 - 3s - loss: 0.5526 - accuracy: 0.8375 - val_loss: 0.5332 - val_accuracy: 0.8437
# Epoch 107/150
# 311/311 - 3s - loss: 0.5510 - accuracy: 0.8386 - val_loss: 0.5994 - val_accuracy: 0.8168
# Epoch 108/150
# 311/311 - 3s - loss: 0.5603 - accuracy: 0.8343 - val_loss: 0.5480 - val_accuracy: 0.8385
# Epoch 109/150
# 311/311 - 4s - loss: 0.5679 - accuracy: 0.8304 - val_loss: 0.5590 - val_accuracy: 0.8335
# Epoch 110/150
# 311/311 - 3s - loss: 0.5457 - accuracy: 0.8394 - val_loss: 0.5264 - val_accuracy: 0.8475
# Epoch 111/150
# 311/311 - 3s - loss: 0.5482 - accuracy: 0.8390 - val_loss: 0.6253 - val_accuracy: 0.8054
# Epoch 112/150
# 311/311 - 3s - loss: 0.5522 - accuracy: 0.8379 - val_loss: 0.5319 - val_accuracy: 0.8438
# Epoch 113/150
# 311/311 - 3s - loss: 0.5439 - accuracy: 0.8396 - val_loss: 0.5306 - val_accuracy: 0.8455
# Epoch 114/150
# 311/311 - 3s - loss: 0.5587 - accuracy: 0.8335 - val_loss: 0.5253 - val_accuracy: 0.8473
# Epoch 115/150
# 311/311 - 3s - loss: 0.5391 - accuracy: 0.8425 - val_loss: 0.5235 - val_accuracy: 0.8480
# Epoch 116/150
# 311/311 - 3s - loss: 0.5395 - accuracy: 0.8418 - val_loss: 0.5324 - val_accuracy: 0.8442
# Epoch 117/150
# 311/311 - 3s - loss: 0.5536 - accuracy: 0.8359 - val_loss: 0.5558 - val_accuracy: 0.8352
# Epoch 118/150
# 311/311 - 3s - loss: 0.5408 - accuracy: 0.8397 - val_loss: 0.5321 - val_accuracy: 0.8439
# Epoch 119/150
# 311/311 - 3s - loss: 0.5309 - accuracy: 0.8446 - val_loss: 0.5342 - val_accuracy: 0.8434
# Epoch 120/150
# 311/311 - 3s - loss: 0.5326 - accuracy: 0.8443 - val_loss: 0.5177 - val_accuracy: 0.8492
# Epoch 121/150
# 311/311 - 3s - loss: 0.5243 - accuracy: 0.8479 - val_loss: 0.5295 - val_accuracy: 0.8430
# Epoch 122/150
# 311/311 - 3s - loss: 0.5690 - accuracy: 0.8319 - val_loss: 0.5265 - val_accuracy: 0.8473
# Epoch 123/150
# 311/311 - 3s - loss: 0.5303 - accuracy: 0.8449 - val_loss: 0.5140 - val_accuracy: 0.8504
# Epoch 124/150
# 311/311 - 3s - loss: 0.5240 - accuracy: 0.8476 - val_loss: 0.5197 - val_accuracy: 0.8474
# Epoch 125/150
# 311/311 - 3s - loss: 0.5695 - accuracy: 0.8306 - val_loss: 0.5189 - val_accuracy: 0.8508
# Epoch 126/150
# 311/311 - 4s - loss: 0.5237 - accuracy: 0.8467 - val_loss: 0.5241 - val_accuracy: 0.8451
# Epoch 127/150
# 311/311 - 3s - loss: 0.5171 - accuracy: 0.8495 - val_loss: 0.5636 - val_accuracy: 0.8287
# Epoch 128/150
# 311/311 - 3s - loss: 0.5241 - accuracy: 0.8469 - val_loss: 0.5443 - val_accuracy: 0.8357
# Epoch 129/150
# 311/311 - 4s - loss: 0.5189 - accuracy: 0.8481 - val_loss: 0.5366 - val_accuracy: 0.8401
# Epoch 130/150
# 311/311 - 4s - loss: 0.5444 - accuracy: 0.8404 - val_loss: 0.5109 - val_accuracy: 0.8529
# Epoch 131/150
# 311/311 - 3s - loss: 0.5126 - accuracy: 0.8511 - val_loss: 0.5110 - val_accuracy: 0.8505
# Epoch 132/150
# 311/311 - 3s - loss: 0.5203 - accuracy: 0.8486 - val_loss: 0.5522 - val_accuracy: 0.8372
# Epoch 133/150
# 311/311 - 3s - loss: 0.5182 - accuracy: 0.8485 - val_loss: 0.5050 - val_accuracy: 0.8526
# Epoch 134/150
# 311/311 - 3s - loss: 0.5250 - accuracy: 0.8456 - val_loss: 0.5224 - val_accuracy: 0.8467
# Epoch 135/150
# 311/311 - 3s - loss: 0.5111 - accuracy: 0.8506 - val_loss: 0.5218 - val_accuracy: 0.8472
# Epoch 136/150
# 311/311 - 3s - loss: 0.5216 - accuracy: 0.8472 - val_loss: 0.5040 - val_accuracy: 0.8531
# Epoch 137/150
# 311/311 - 3s - loss: 0.5046 - accuracy: 0.8535 - val_loss: 0.5062 - val_accuracy: 0.8513
# Epoch 138/150
# 311/311 - 3s - loss: 0.5143 - accuracy: 0.8495 - val_loss: 0.5174 - val_accuracy: 0.8487
# Epoch 139/150
# 311/311 - 3s - loss: 0.5010 - accuracy: 0.8551 - val_loss: 0.4996 - val_accuracy: 0.8540
# Epoch 140/150
# 311/311 - 3s - loss: 0.5127 - accuracy: 0.8507 - val_loss: 0.5074 - val_accuracy: 0.8512
# Epoch 141/150
# 311/311 - 3s - loss: 0.4998 - accuracy: 0.8548 - val_loss: 0.4998 - val_accuracy: 0.8545
# Epoch 142/150
# 311/311 - 3s - loss: 0.5076 - accuracy: 0.8514 - val_loss: 0.5147 - val_accuracy: 0.8490
# Epoch 143/150
# 311/311 - 3s - loss: 0.5247 - accuracy: 0.8447 - val_loss: 0.5077 - val_accuracy: 0.8518
# Epoch 144/150
# 311/311 - 3s - loss: 0.4978 - accuracy: 0.8553 - val_loss: 0.5229 - val_accuracy: 0.8458
# Epoch 145/150
# 311/311 - 3s - loss: 0.5338 - accuracy: 0.8412 - val_loss: 0.5227 - val_accuracy: 0.8471
# Epoch 146/150
# 311/311 - 3s - loss: 0.4982 - accuracy: 0.8555 - val_loss: 0.5001 - val_accuracy: 0.8540
# Epoch 147/150
# 311/311 - 3s - loss: 0.4988 - accuracy: 0.8549 - val_loss: 0.4933 - val_accuracy: 0.8559
# Epoch 148/150
# 311/311 - 3s - loss: 0.5013 - accuracy: 0.8539 - val_loss: 0.4948 - val_accuracy: 0.8554
# Epoch 149/150
# 311/311 - 3s - loss: 0.5187 - accuracy: 0.8475 - val_loss: 0.5180 - val_accuracy: 0.8485
# Epoch 150/150
# 311/311 - 3s - loss: 0.4936 - accuracy: 0.8563 - val_loss: 0.5050 - val_accuracy: 0.8516

# %%
hist2 = model8.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=150,verbose=2)
# Out:
# Train on 311 samples, validate on 56 samples
# Epoch 1/150
# 311/311 - 3s - loss: 0.5019 - accuracy: 0.8530 - val_loss: 0.5066 - val_accuracy: 0.8510
# Epoch 2/150
# 311/311 - 3s - loss: 0.4941 - accuracy: 0.8558 - val_loss: 0.5030 - val_accuracy: 0.8510
# Epoch 3/150
# 311/311 - 3s - loss: 0.4909 - accuracy: 0.8567 - val_loss: 0.5050 - val_accuracy: 0.8533
# Epoch 4/150
# 311/311 - 3s - loss: 0.4904 - accuracy: 0.8570 - val_loss: 0.4926 - val_accuracy: 0.8554
# Epoch 5/150
# 311/311 - 3s - loss: 0.4857 - accuracy: 0.8595 - val_loss: 0.5067 - val_accuracy: 0.8498
# Epoch 6/150
# 311/311 - 3s - loss: 0.5060 - accuracy: 0.8510 - val_loss: 0.5884 - val_accuracy: 0.8292
# Epoch 7/150
# 311/311 - 3s - loss: 0.5261 - accuracy: 0.8447 - val_loss: 0.4929 - val_accuracy: 0.8567
# Epoch 8/150
# 311/311 - 3s - loss: 0.4838 - accuracy: 0.8599 - val_loss: 0.4875 - val_accuracy: 0.8580
# Epoch 9/150
# 311/311 - 3s - loss: 0.4800 - accuracy: 0.8611 - val_loss: 0.4941 - val_accuracy: 0.8548
# Epoch 10/150
# 311/311 - 3s - loss: 0.5110 - accuracy: 0.8488 - val_loss: 0.4984 - val_accuracy: 0.8550
# Epoch 11/150
# 311/311 - 3s - loss: 0.4837 - accuracy: 0.8593 - val_loss: 0.4967 - val_accuracy: 0.8547
# Epoch 12/150
# 311/311 - 3s - loss: 0.4910 - accuracy: 0.8573 - val_loss: 0.4878 - val_accuracy: 0.8575
# Epoch 13/150
# 311/311 - 3s - loss: 0.4948 - accuracy: 0.8544 - val_loss: 0.4989 - val_accuracy: 0.8537
# Epoch 14/150
# 311/311 - 3s - loss: 0.4851 - accuracy: 0.8587 - val_loss: 0.4936 - val_accuracy: 0.8554
# Epoch 15/150
# 311/311 - 3s - loss: 0.4757 - accuracy: 0.8622 - val_loss: 0.5137 - val_accuracy: 0.8489
# Epoch 16/150
# 311/311 - 3s - loss: 0.4820 - accuracy: 0.8593 - val_loss: 0.4914 - val_accuracy: 0.8552
# Epoch 17/150
# 311/311 - 3s - loss: 0.4787 - accuracy: 0.8610 - val_loss: 0.5049 - val_accuracy: 0.8529
# Epoch 18/150
# 311/311 - 3s - loss: 0.4797 - accuracy: 0.8606 - val_loss: 0.4838 - val_accuracy: 0.8583
# Epoch 19/150
# 311/311 - 3s - loss: 0.4803 - accuracy: 0.8605 - val_loss: 0.5913 - val_accuracy: 0.8181
# Epoch 20/150
# 311/311 - 3s - loss: 0.4802 - accuracy: 0.8604 - val_loss: 0.5011 - val_accuracy: 0.8523
# Epoch 21/150
# 311/311 - 3s - loss: 0.4834 - accuracy: 0.8584 - val_loss: 0.5793 - val_accuracy: 0.8269
# Epoch 22/150
# 311/311 - 3s - loss: 0.5061 - accuracy: 0.8507 - val_loss: 0.4822 - val_accuracy: 0.8599
# Epoch 23/150
# 311/311 - 3s - loss: 0.4684 - accuracy: 0.8645 - val_loss: 0.4798 - val_accuracy: 0.8598
# Epoch 24/150
# 311/311 - 3s - loss: 0.4675 - accuracy: 0.8643 - val_loss: 0.4816 - val_accuracy: 0.8588
# Epoch 25/150
# 311/311 - 3s - loss: 0.4674 - accuracy: 0.8648 - val_loss: 0.4852 - val_accuracy: 0.8569
# Epoch 26/150
# 311/311 - 3s - loss: 0.4912 - accuracy: 0.8566 - val_loss: 0.5418 - val_accuracy: 0.8417
# Epoch 27/150
# 311/311 - 3s - loss: 0.4856 - accuracy: 0.8584 - val_loss: 0.4885 - val_accuracy: 0.8583
# Epoch 28/150
# 311/311 - 3s - loss: 0.4668 - accuracy: 0.8652 - val_loss: 0.4839 - val_accuracy: 0.8573
# Epoch 29/150
# 311/311 - 3s - loss: 0.4623 - accuracy: 0.8660 - val_loss: 0.4826 - val_accuracy: 0.8582
# Epoch 30/150
# 311/311 - 3s - loss: 0.4691 - accuracy: 0.8642 - val_loss: 0.5157 - val_accuracy: 0.8466
# Epoch 31/150
# 311/311 - 3s - loss: 0.4798 - accuracy: 0.8606 - val_loss: 0.4773 - val_accuracy: 0.8606
# Epoch 32/150
# 311/311 - 3s - loss: 0.4606 - accuracy: 0.8671 - val_loss: 0.4897 - val_accuracy: 0.8556
# Epoch 33/150
# 311/311 - 3s - loss: 0.4645 - accuracy: 0.8648 - val_loss: 0.4741 - val_accuracy: 0.8612
# Epoch 34/150
# 311/311 - 3s - loss: 0.4644 - accuracy: 0.8657 - val_loss: 0.6092 - val_accuracy: 0.8132
# Epoch 35/150
# 311/311 - 3s - loss: 0.5211 - accuracy: 0.8461 - val_loss: 0.4775 - val_accuracy: 0.8613
# Epoch 36/150
# 311/311 - 3s - loss: 0.4594 - accuracy: 0.8673 - val_loss: 0.4771 - val_accuracy: 0.8598
# Epoch 37/150
# 311/311 - 3s - loss: 0.4571 - accuracy: 0.8677 - val_loss: 0.4823 - val_accuracy: 0.8608
# Epoch 38/150
# 311/311 - 3s - loss: 0.4560 - accuracy: 0.8678 - val_loss: 0.5127 - val_accuracy: 0.8463
# Epoch 39/150
# 311/311 - 3s - loss: 0.4691 - accuracy: 0.8641 - val_loss: 0.4970 - val_accuracy: 0.8518
# Epoch 40/150
# 311/311 - 3s - loss: 0.4625 - accuracy: 0.8653 - val_loss: 0.4985 - val_accuracy: 0.8512
# Epoch 41/150
# 311/311 - 3s - loss: 0.4630 - accuracy: 0.8653 - val_loss: 0.4756 - val_accuracy: 0.8615
# Epoch 42/150
# 311/311 - 3s - loss: 0.4524 - accuracy: 0.8702 - val_loss: 0.4837 - val_accuracy: 0.8572
# Epoch 43/150
# 311/311 - 3s - loss: 0.4686 - accuracy: 0.8632 - val_loss: 0.6087 - val_accuracy: 0.8124
# Epoch 44/150
# 311/311 - 3s - loss: 0.4752 - accuracy: 0.8604 - val_loss: 0.4735 - val_accuracy: 0.8609
# Epoch 45/150
# 311/311 - 3s - loss: 0.4491 - accuracy: 0.8706 - val_loss: 0.4728 - val_accuracy: 0.8612
# Epoch 46/150
# 311/311 - 3s - loss: 0.4518 - accuracy: 0.8697 - val_loss: 0.4800 - val_accuracy: 0.8592
# Epoch 47/150
# 311/311 - 3s - loss: 0.4529 - accuracy: 0.8690 - val_loss: 0.4755 - val_accuracy: 0.8613
# Epoch 48/150
# 311/311 - 3s - loss: 0.4458 - accuracy: 0.8715 - val_loss: 0.4736 - val_accuracy: 0.8621
# Epoch 49/150
# 311/311 - 3s - loss: 0.4573 - accuracy: 0.8673 - val_loss: 0.4814 - val_accuracy: 0.8596
# Epoch 50/150
# 311/311 - 3s - loss: 0.4453 - accuracy: 0.8717 - val_loss: 0.4704 - val_accuracy: 0.8629
# Epoch 51/150
# 311/311 - 3s - loss: 0.4511 - accuracy: 0.8702 - val_loss: 0.5134 - val_accuracy: 0.8460
# Epoch 52/150
# 311/311 - 3s - loss: 0.4847 - accuracy: 0.8565 - val_loss: 0.4700 - val_accuracy: 0.8629
# Epoch 53/150
# 311/311 - 3s - loss: 0.4539 - accuracy: 0.8685 - val_loss: 0.4701 - val_accuracy: 0.8630
# Epoch 54/150
# 311/311 - 3s - loss: 0.4422 - accuracy: 0.8734 - val_loss: 0.4664 - val_accuracy: 0.8635
# Epoch 55/150
# 311/311 - 3s - loss: 0.4501 - accuracy: 0.8696 - val_loss: 0.4694 - val_accuracy: 0.8628
# Epoch 56/150
# 311/311 - 3s - loss: 0.4452 - accuracy: 0.8716 - val_loss: 0.4838 - val_accuracy: 0.8574
# Epoch 57/150
# 311/311 - 3s - loss: 0.4471 - accuracy: 0.8709 - val_loss: 0.4707 - val_accuracy: 0.8623
# Epoch 58/150
# 311/311 - 3s - loss: 0.4558 - accuracy: 0.8677 - val_loss: 0.4796 - val_accuracy: 0.8582
# Epoch 59/150
# 311/311 - 3s - loss: 0.4402 - accuracy: 0.8735 - val_loss: 0.4718 - val_accuracy: 0.8619
# Epoch 60/150
# 311/311 - 3s - loss: 0.4732 - accuracy: 0.8613 - val_loss: 0.5074 - val_accuracy: 0.8480
# Epoch 61/150
# 311/311 - 3s - loss: 0.4432 - accuracy: 0.8723 - val_loss: 0.4684 - val_accuracy: 0.8627
# Epoch 62/150
# 311/311 - 3s - loss: 0.4376 - accuracy: 0.8743 - val_loss: 0.4639 - val_accuracy: 0.8648
# Epoch 63/150
# 311/311 - 3s - loss: 0.4363 - accuracy: 0.8744 - val_loss: 0.5181 - val_accuracy: 0.8458
# Epoch 64/150
# 311/311 - 3s - loss: 0.4531 - accuracy: 0.8688 - val_loss: 0.4642 - val_accuracy: 0.8648
# Epoch 65/150
# 311/311 - 3s - loss: 0.4381 - accuracy: 0.8737 - val_loss: 0.4698 - val_accuracy: 0.8610
# Epoch 66/150
# 311/311 - 3s - loss: 0.4704 - accuracy: 0.8626 - val_loss: 0.4679 - val_accuracy: 0.8628
# Epoch 67/150
# 311/311 - 3s - loss: 0.4380 - accuracy: 0.8740 - val_loss: 0.4713 - val_accuracy: 0.8613
# Epoch 68/150
# 311/311 - 3s - loss: 0.4370 - accuracy: 0.8744 - val_loss: 0.4652 - val_accuracy: 0.8642
# Epoch 69/150
# 311/311 - 3s - loss: 0.4446 - accuracy: 0.8706 - val_loss: 0.4688 - val_accuracy: 0.8630
# Epoch 70/150
# 311/311 - 3s - loss: 0.4526 - accuracy: 0.8681 - val_loss: 0.4718 - val_accuracy: 0.8617
# Epoch 71/150
# 311/311 - 3s - loss: 0.4387 - accuracy: 0.8739 - val_loss: 0.5137 - val_accuracy: 0.8475
# Epoch 72/150
# 311/311 - 3s - loss: 0.4477 - accuracy: 0.8710 - val_loss: 0.4740 - val_accuracy: 0.8603
# Epoch 73/150
# 311/311 - 3s - loss: 0.4332 - accuracy: 0.8756 - val_loss: 0.4613 - val_accuracy: 0.8652
# Epoch 74/150
# 311/311 - 3s - loss: 0.4286 - accuracy: 0.8771 - val_loss: 0.4647 - val_accuracy: 0.8635
# Epoch 75/150
# 311/311 - 3s - loss: 0.4324 - accuracy: 0.8758 - val_loss: 0.4902 - val_accuracy: 0.8569
# Epoch 76/150
# 311/311 - 3s - loss: 0.4502 - accuracy: 0.8692 - val_loss: 0.4620 - val_accuracy: 0.8653
# Epoch 77/150
# 311/311 - 3s - loss: 0.4300 - accuracy: 0.8765 - val_loss: 0.4709 - val_accuracy: 0.8608
# Epoch 78/150
# 311/311 - 3s - loss: 0.4261 - accuracy: 0.8782 - val_loss: 0.4595 - val_accuracy: 0.8656
# Epoch 79/150
# 311/311 - 3s - loss: 0.4273 - accuracy: 0.8778 - val_loss: 0.4690 - val_accuracy: 0.8621
# Epoch 80/150
# 311/311 - 3s - loss: 0.4575 - accuracy: 0.8661 - val_loss: 0.5820 - val_accuracy: 0.8239
# Epoch 81/150
# 311/311 - 3s - loss: 0.4650 - accuracy: 0.8654 - val_loss: 0.4609 - val_accuracy: 0.8654
# Epoch 82/150
# 311/311 - 3s - loss: 0.4262 - accuracy: 0.8781 - val_loss: 0.4569 - val_accuracy: 0.8667
# Epoch 83/150
# 311/311 - 3s - loss: 0.4236 - accuracy: 0.8790 - val_loss: 0.4621 - val_accuracy: 0.8646
# Epoch 84/150
# 311/311 - 3s - loss: 0.4268 - accuracy: 0.8777 - val_loss: 0.4743 - val_accuracy: 0.8610
# Epoch 85/150
# 311/311 - 3s - loss: 0.4356 - accuracy: 0.8748 - val_loss: 0.4604 - val_accuracy: 0.8659
# Epoch 86/150
# 311/311 - 3s - loss: 0.4344 - accuracy: 0.8745 - val_loss: 0.5136 - val_accuracy: 0.8458
# Epoch 87/150
# 311/311 - 3s - loss: 0.4465 - accuracy: 0.8698 - val_loss: 0.4585 - val_accuracy: 0.8658
# Epoch 88/150
# 311/311 - 3s - loss: 0.4246 - accuracy: 0.8783 - val_loss: 0.4621 - val_accuracy: 0.8649
# Epoch 89/150
# 311/311 - 3s - loss: 0.4334 - accuracy: 0.8745 - val_loss: 0.4698 - val_accuracy: 0.8628
# Epoch 90/150
# 311/311 - 3s - loss: 0.4285 - accuracy: 0.8771 - val_loss: 0.4942 - val_accuracy: 0.8514
# Epoch 91/150
# 311/311 - 3s - loss: 0.4324 - accuracy: 0.8750 - val_loss: 0.4581 - val_accuracy: 0.8667
# Epoch 92/150
# 311/311 - 3s - loss: 0.4257 - accuracy: 0.8776 - val_loss: 0.4591 - val_accuracy: 0.8660
# Epoch 93/150
# 311/311 - 3s - loss: 0.4180 - accuracy: 0.8804 - val_loss: 0.4573 - val_accuracy: 0.8665
# Epoch 94/150
# 311/311 - 3s - loss: 0.4239 - accuracy: 0.8786 - val_loss: 0.4673 - val_accuracy: 0.8620
# Epoch 95/150
# 311/311 - 3s - loss: 0.4337 - accuracy: 0.8737 - val_loss: 0.4652 - val_accuracy: 0.8654
# Epoch 96/150
# 311/311 - 3s - loss: 0.4300 - accuracy: 0.8756 - val_loss: 0.4649 - val_accuracy: 0.8650
# Epoch 97/150
# 311/311 - 3s - loss: 0.4322 - accuracy: 0.8750 - val_loss: 0.4556 - val_accuracy: 0.8670
# Epoch 98/150
# 311/311 - 3s - loss: 0.4196 - accuracy: 0.8800 - val_loss: 0.4598 - val_accuracy: 0.8670
# Epoch 99/150
# 311/311 - 3s - loss: 0.4162 - accuracy: 0.8811 - val_loss: 0.4570 - val_accuracy: 0.8663
# Epoch 100/150
# 311/311 - 3s - loss: 0.4181 - accuracy: 0.8803 - val_loss: 0.4595 - val_accuracy: 0.8654
# Epoch 101/150
# 311/311 - 3s - loss: 0.4243 - accuracy: 0.8783 - val_loss: 0.4595 - val_accuracy: 0.8661
# Epoch 102/150
# 311/311 - 3s - loss: 0.4242 - accuracy: 0.8777 - val_loss: 0.4641 - val_accuracy: 0.8641
# Epoch 103/150
# 311/311 - 3s - loss: 0.4173 - accuracy: 0.8806 - val_loss: 0.4971 - val_accuracy: 0.8508
# Epoch 104/150
# 311/311 - 3s - loss: 0.4528 - accuracy: 0.8689 - val_loss: 0.4713 - val_accuracy: 0.8626
# Epoch 105/150
# 311/311 - 3s - loss: 0.4181 - accuracy: 0.8803 - val_loss: 0.4532 - val_accuracy: 0.8675
# Epoch 106/150
# 311/311 - 3s - loss: 0.4127 - accuracy: 0.8821 - val_loss: 0.4583 - val_accuracy: 0.8658
# Epoch 107/150
# 311/311 - 3s - loss: 0.4156 - accuracy: 0.8813 - val_loss: 0.4642 - val_accuracy: 0.8632
# Epoch 108/150
# 311/311 - 3s - loss: 0.4333 - accuracy: 0.8748 - val_loss: 0.4766 - val_accuracy: 0.8602
# Epoch 109/150
# 311/311 - 3s - loss: 0.4180 - accuracy: 0.8799 - val_loss: 0.4522 - val_accuracy: 0.8682
# Epoch 110/150
# 311/311 - 3s - loss: 0.4094 - accuracy: 0.8833 - val_loss: 0.4593 - val_accuracy: 0.8660
# Epoch 111/150
# 311/311 - 3s - loss: 0.4128 - accuracy: 0.8819 - val_loss: 0.4714 - val_accuracy: 0.8602
# Epoch 112/150
# 311/311 - 3s - loss: 0.4340 - accuracy: 0.8739 - val_loss: 0.4571 - val_accuracy: 0.8667
# Epoch 113/150
# 311/311 - 3s - loss: 0.4128 - accuracy: 0.8816 - val_loss: 0.4611 - val_accuracy: 0.8639
# Epoch 114/150
# 311/311 - 3s - loss: 0.4117 - accuracy: 0.8824 - val_loss: 0.4640 - val_accuracy: 0.8647
# Epoch 115/150
# 311/311 - 3s - loss: 0.4156 - accuracy: 0.8810 - val_loss: 0.4837 - val_accuracy: 0.8594
# Epoch 116/150
# 311/311 - 3s - loss: 0.4238 - accuracy: 0.8778 - val_loss: 0.4821 - val_accuracy: 0.8561
# Epoch 117/150
# 311/311 - 3s - loss: 0.4249 - accuracy: 0.8762 - val_loss: 0.4805 - val_accuracy: 0.8595
# Epoch 118/150
# 311/311 - 3s - loss: 0.4268 - accuracy: 0.8775 - val_loss: 0.4527 - val_accuracy: 0.8681
# Epoch 119/150
# 311/311 - 3s - loss: 0.4047 - accuracy: 0.8847 - val_loss: 0.4522 - val_accuracy: 0.8683
# Epoch 120/150
# 311/311 - 3s - loss: 0.4063 - accuracy: 0.8841 - val_loss: 0.4525 - val_accuracy: 0.8677
# Epoch 121/150
# 311/311 - 3s - loss: 0.4088 - accuracy: 0.8832 - val_loss: 0.4556 - val_accuracy: 0.8675
# Epoch 122/150
# 311/311 - 3s - loss: 0.4072 - accuracy: 0.8841 - val_loss: 0.4553 - val_accuracy: 0.8669
# Epoch 123/150
# 311/311 - 3s - loss: 0.4076 - accuracy: 0.8837 - val_loss: 0.4737 - val_accuracy: 0.8591
# Epoch 124/150
# 311/311 - 3s - loss: 0.4469 - accuracy: 0.8691 - val_loss: 0.4570 - val_accuracy: 0.8664
# Epoch 125/150
# 311/311 - 4s - loss: 0.4059 - accuracy: 0.8838 - val_loss: 0.4507 - val_accuracy: 0.8685
# Epoch 126/150
# 311/311 - 3s - loss: 0.4030 - accuracy: 0.8852 - val_loss: 0.4535 - val_accuracy: 0.8666
# Epoch 127/150
# 311/311 - 3s - loss: 0.4100 - accuracy: 0.8823 - val_loss: 0.4550 - val_accuracy: 0.8682
# Epoch 128/150
# 311/311 - 3s - loss: 0.4061 - accuracy: 0.8836 - val_loss: 0.4646 - val_accuracy: 0.8641
# Epoch 129/150
# 311/311 - 3s - loss: 0.4104 - accuracy: 0.8820 - val_loss: 0.4522 - val_accuracy: 0.8681
# Epoch 130/150
# 311/311 - 3s - loss: 0.4146 - accuracy: 0.8814 - val_loss: 0.4700 - val_accuracy: 0.8637
# Epoch 131/150
# 311/311 - 3s - loss: 0.4048 - accuracy: 0.8843 - val_loss: 0.4496 - val_accuracy: 0.8687
# Epoch 132/150
# 311/311 - 3s - loss: 0.3994 - accuracy: 0.8861 - val_loss: 0.4521 - val_accuracy: 0.8689
# Epoch 133/150
# 311/311 - 3s - loss: 0.4020 - accuracy: 0.8854 - val_loss: 0.4590 - val_accuracy: 0.8660
# Epoch 134/150
# 311/311 - 3s - loss: 0.4257 - accuracy: 0.8764 - val_loss: 0.5100 - val_accuracy: 0.8541
# Epoch 135/150
# 311/311 - 3s - loss: 0.4224 - accuracy: 0.8780 - val_loss: 0.4532 - val_accuracy: 0.8688
# Epoch 136/150
# 311/311 - 3s - loss: 0.4062 - accuracy: 0.8839 - val_loss: 0.4510 - val_accuracy: 0.8684
# Epoch 137/150
# 311/311 - 3s - loss: 0.4015 - accuracy: 0.8855 - val_loss: 0.4568 - val_accuracy: 0.8661
# Epoch 138/150
# 311/311 - 3s - loss: 0.4113 - accuracy: 0.8816 - val_loss: 0.4603 - val_accuracy: 0.8638
# Epoch 139/150
# 311/311 - 3s - loss: 0.4077 - accuracy: 0.8829 - val_loss: 0.4497 - val_accuracy: 0.8692
# Epoch 140/150
# 311/311 - 4s - loss: 0.4004 - accuracy: 0.8857 - val_loss: 0.4630 - val_accuracy: 0.8629
# Epoch 141/150
# 311/311 - 4s - loss: 0.4116 - accuracy: 0.8809 - val_loss: 0.4778 - val_accuracy: 0.8633
# Epoch 142/150
# 311/311 - 3s - loss: 0.4143 - accuracy: 0.8807 - val_loss: 0.4634 - val_accuracy: 0.8641
# Epoch 143/150
# 311/311 - 3s - loss: 0.3978 - accuracy: 0.8862 - val_loss: 0.4515 - val_accuracy: 0.8685
# Epoch 144/150
# 311/311 - 3s - loss: 0.3972 - accuracy: 0.8866 - val_loss: 0.4585 - val_accuracy: 0.8664
# Epoch 145/150
# 311/311 - 3s - loss: 0.3982 - accuracy: 0.8866 - val_loss: 0.4506 - val_accuracy: 0.8693
# Epoch 146/150
# 311/311 - 3s - loss: 0.4021 - accuracy: 0.8850 - val_loss: 0.4849 - val_accuracy: 0.8569
# Epoch 147/150
# 311/311 - 3s - loss: 0.4100 - accuracy: 0.8827 - val_loss: 0.4672 - val_accuracy: 0.8609
# Epoch 148/150
# 311/311 - 3s - loss: 0.4051 - accuracy: 0.8833 - val_loss: 0.4544 - val_accuracy: 0.8677
# Epoch 149/150
# 311/311 - 3s - loss: 0.4001 - accuracy: 0.8853 - val_loss: 0.4636 - val_accuracy: 0.8657
# Epoch 150/150
# 311/311 - 3s - loss: 0.4002 - accuracy: 0.8853 - val_loss: 0.4518 - val_accuracy: 0.8679

# %%
#save the weights
model8.save("model8.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # test: prediction and visual

# %%
#get test part of dataset

def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        # 1 means input a colored images, while 0 or 2 represent grayscale image. other numbers will get the colored output
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):    
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

dir_test_seg = "/content/Colab Notebooks/dataset1/annotations_prepped_test/"# annotations_prepped_train   Don't forget to write "." in front of /
dir_test_img = "/content/Colab Notebooks/dataset1/images_prepped_test/"# images_prepped_train
  
test_images = os.listdir(dir_test_img)
test_images.sort()#sort it
test_segmentations  = os.listdir(dir_test_seg)
test_segmentations.sort()
    
imgs = []
segs = []
input_width=224
input_height=224
output_width=224
output_height=224

for im , seg in zip(test_images,test_segmentations) :#zip is generator and returns to list[(),(),......],im and seg here are the names of images
    imgs.append( getImageArr(dir_test_img +"/"+ im , input_width , input_height )  )
    segs.append( getSegmentationArr( dir_test_seg +"/"+ seg , n_classes , output_width , output_height )  )

imgs, segs = np.array(imgs) , np.array(segs)
print(imgs.shape,segs.shape)
# Out:
# (101, 224, 224, 3) (101, 224, 224, 12)

# %%
#make predictions by keras.Model.predicit
predictions=model8.predict(imgs, batch_size=None)
#print(predictions.shape) -> output:(101,224,224,12)

#make it to be 1 or 0
predictions=(predictions+0.5).astype(int)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.

# %%
#functions for visualize
import numpy as np
def give_color_to_seg_img(seg,n_classes):
    seg_img=np.zeros(seg.shape) #note:seg is a 3_dimension image!!
    for i in range(n_classes):
        indexh=np.where(seg==i)[0]
        indexw=np.where(seg==i)[1]
        seg_img[indexh,indexw,:]= sns.color_palette("hls", n_classes)[i]
    return(seg_img)
def visualize(output):#a function converts 12-dimension to 3-dimension; values changed from 0/1 to 0-11
    img=np.zeros((224,224,3))
    for i in range (224):
        for j in range(224):
            index=np.where(output[i,j,:]==np.max(output[i,j,:]))[0][0]
            img[i,j,:]=index
    seg_img = give_color_to_seg_img(img,n_classes).astype(np.float)#image should be 3-dimension input
    plt.imshow(seg_img)
def choose_a_images_to_compare(num):#input index of images
    
    plt.imshow(((imgs[num]+1)*127.5).astype(np.int32))
    plt.title(str(num+1)+'th image')
    plt.show()

    #annotations_prepped_test
    plt.subplot(1,2,1)
    visualize(segs[num])
    plt.title(str(num+1)+'th ground truth')
    plt.subplot(1,2,2)
    visualize(predictions[num])
    plt.title(str(num+1)+'th segmentation')
    plt.show()

# %%
#call the function
choose_a_images_to_compare(0)

#intersection = np.logical_and(segs, predictions)
#union = np.logical_or(segs, predictions)
#iou_score = np.sum(intersection) / np.sum(union)
#print('mIoU for all test images',iou_score)

# %% [markdown]
# #Doctor's metric to test

# %%
#convert predictions to 3-d type
def convert_12d_to_3d(output):
    img=np.zeros((224,224,3))
    for i in range (224):
        for j in range(224):
                index=np.where(output[i,j,:]==np.max(output[i,j,:]))[0][0]
                img[i,j,:]=index
    return img
def convert_12d_dataset_to_3d(predictions):
  predictions_tem=np.zeros((predictions.shape[0],predictions.shape[1],predictions.shape[2],3))
  for i in range(predictions.shape[0]):
    predictions_tem[i]=convert_12d_to_3d(predictions[i])
  return predictions_tem
  
#predictions_tem is 3-d type of predictions, ranging from 0 to 11

# %%
Yi=convert_12d_dataset_to_3d(segs)
y_predi=convert_12d_dataset_to_3d(predictions)

# %%
print('Yi.shape:',Yi.shape)
print('y_predi.shape:',y_predi.shape)
# Out:
# Yi.shape: (101, 224, 224, 3)
# y_predi.shape: (101, 224, 224, 3)

# %%
def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))
    
IoU(Yi,y_predi)
# Out:
# class 00: #TP=1332456, #FP=1576734, #FN=35463, IoU=0.453
# class 01: #TP=3131589, #FP=350784, #FN=780249, IoU=0.735
# class 02: #TP=     0, #FP=     0, #FN=109260, IoU=0.000
# class 03: #TP=4204368, #FP=150261, #FN=220689, IoU=0.919
# class 04: #TP=1109046, #FP=157896, #FN=236253, IoU=0.738
# class 05: #TP=2200086, #FP=161616, #FN=279549, IoU=0.833
# class 06: #TP=    15, #FP=     0, #FN=160161, IoU=0.000
# class 07: #TP=197379, #FP=152817, #FN=271830, IoU=0.317
# class 08: #TP=179559, #FP= 66585, #FN=102621, IoU=0.515
# class 09: #TP=  8991, #FP=  8742, #FN=101604, IoU=0.075
# class 10: #TP= 18300, #FP=  7320, #FN=314616, IoU=0.054
# class 11: #TP= 21480, #FP=167304, #FN=187764, IoU=0.057
# _________________
# Mean IoU: 0.391
